# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %%
# Try to print or display it nicely.

df_food.head(125)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.
df_info = pd.DataFrame({"dtypes" : df_food.dtypes, "counts" : df_food.count()})
df_info
# Out:
#                                dtypes  counts
# GPA                               str     123
# Gender                          int64     125
# breakfast                       int64     125
# calories_chicken                int64     125
# calories_day                  float64     106
# calories_scone                float64     124
# coffee                          int64     125
# comfort_food                      str     124
# comfort_food_reasons              str     123
# comfort_food_reasons_coded    float64     106
# cook                          float64     122
# comfort_food_reasons_coded.1    int64     125
# cuisine                       float64     108
# diet_current                      str     124
# diet_current_coded              int64     125
# drink                         float64     123
# eating_changes                    str     122
# eating_changes_coded            int64     125
# eating_changes_coded1           int64     125
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.
keep = ["Gender", "weight", "calories_day"]
df_food_col_subset = df_food[keep]
df_food_col_subset
# Out:
#      Gender                    weight  calories_day
# 0         2                       187           NaN
# 1         1                       155           3.0
# 2         1  I'm not answering this.            4.0
# 3         1             Not sure, 240           3.0
# 4         1                       190           2.0
# ..      ...                       ...           ...
# 120       1                       156           4.0
# 121       1                       180           2.0
# 122       1                       120           NaN
# 123       2                       135           4.0
# 124       1                       135           NaN
#
# [125 rows x 3 columns]

# %%
# Is there a second way to remove columns?
remove = set(df_food.columns.to_list())
remove.remove("Gender")
remove.remove("weight")
remove.remove("calories_day")

df_food_col_subset = df_food.drop(columns = list(remove))

df_food_col_subset
# Out:
#      Gender  calories_day                    weight
# 0         2           NaN                       187
# 1         1           3.0                       155
# 2         1           4.0  I'm not answering this.
# 3         1           3.0             Not sure, 240
# 4         1           2.0                       190
# ..      ...           ...                       ...
# 120       1           4.0                       156
# 121       1           2.0                       180
# 122       1           NaN                       120
# 123       2           4.0                       135
# 124       1           NaN                       135
#
# [125 rows x 3 columns]

# %%
# 🚀 Extra credit: What about a third way to remove columns?

df_food_col_subset = df_food.loc[:, keep]
df_food_col_subset
# Out:
#      Gender                    weight  calories_day
# 0         2                       187           NaN
# 1         1                       155           3.0
# 2         1  I'm not answering this.            4.0
# 3         1             Not sure, 240           3.0
# 4         1                       190           2.0
# ..      ...                       ...           ...
# 120       1                       156           4.0
# 121       1                       180           2.0
# 122       1                       120           NaN
# 123       2                       135           4.0
# 124       1                       135           NaN
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food.isnull().sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# ...

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

df_food_nan = df_food.isna().sum().to_frame()
df_food_nan
# Out:
#                                0
# GPA                            2
# Gender                         0
# breakfast                      0
# calories_chicken               0
# calories_day                  19
# calories_scone                 1
# coffee                         0
# comfort_food                   1
# comfort_food_reasons           2
# comfort_food_reasons_coded    19
# cook                           3
# comfort_food_reasons_coded.1   0
# cuisine                       17
# diet_current                   1
# diet_current_coded             0
# drink                          2
# eating_changes                 3
# eating_changes_coded           0
# eating_changes_coded1          0
# eating_out                     0
# employment                     9
# ethnic_food                    0
# exercise                      13
# father_education               1
# father_profession              3
# fav_cuisine                    2
# fav_cuisine_coded              0
# ...

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

df_food_nan = df_food.isna() \
    .sum() \
    .to_frame()

df_food_nan
# Out:
#                                0
# GPA                            2
# Gender                         0
# breakfast                      0
# calories_chicken               0
# calories_day                  19
# calories_scone                 1
# coffee                         0
# comfort_food                   1
# comfort_food_reasons           2
# comfort_food_reasons_coded    19
# cook                           3
# comfort_food_reasons_coded.1   0
# cuisine                       17
# diet_current                   1
# diet_current_coded             0
# drink                          2
# eating_changes                 3
# eating_changes_coded           0
# eating_changes_coded1          0
# eating_out                     0
# employment                     9
# ethnic_food                    0
# exercise                      13
# father_education               1
# father_profession              3
# fav_cuisine                    2
# fav_cuisine_coded              0
# ...

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.
df_food.dropna()
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# ...

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂
df_food
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.
df_food["weight"] = pd.to_numeric(df_food["weight"], errors= "coerce")
df_food = df_food.dropna()
df_food
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# 20          3.3       2          1               610           3.0
# ...

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food.to_csv("food.csv")

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.
df = pd.read_csv("food.csv")

print(df.head(5))
# Out:
#    Unnamed: 0    GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0           1  3.654       1          1               610           3.0
# 1           4    3.5       1          1               720           2.0
# 2           6    3.8       2          1               610           3.0
# 3           7    3.3       1          1               720           3.0
# 4           9    3.3       1          1               430           3.0
#
#    calories_scone  coffee                                  comfort_food  \
# 0           420.0       2                   chocolate, chips, ice cream
# 1           420.0       2                  Ice cream, chocolate, chips
# 2           420.0       2  Chocolate, ice cream, french fries, pretzels
# 3           420.0       1              Ice cream, cheeseburgers, chips.
# 4           315.0       2         Mac and cheese, chocolate, and pasta
#
#                                 comfort_food_reasons  ...  soup  sports  \
# ...

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.

df_manager = pd.read_csv('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')
df_manager
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_manager.shape

# I will not be counting by hand
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_manager.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_manager.columns = ['timestamp', 'age', 'industry', 'job_title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']
df_manager.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'job_title', 'title_context', 'salary',
#        'additional_compensation', 'currency', 'other_currency',
#        'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe',
#        'highest_education_completed', 'gender', 'race'],
#       dtype='str')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_manager['industry'].value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.

df_salary_tech = df_manager[df_manager['industry'] == 'Computing or Tech']

df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                           job_title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.
len(df_salary_tech)
# Out:
# 4699

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!

df_salary_tech = df_salary_tech[df_salary_tech['currency'] == 'USD']

df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                     job_title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech['country'].value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# ...

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.
lf = ['United States', 'USA', 'U.S.', 'United States of America', 'United States']
mask = df_salary_tech['country'].isin(lf)
df_salary_tech.loc[mask, 'country'] = 'US'

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary_tech['country'].value_counts()
# Out:
# country
# US                           3408
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# ...

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
lf = ['united states', 'usa', 'united states of america', 'us']
df_salary_tech['country'] = df_salary_tech['country'].str.strip().str.lower().str.replace('.', '')

mask = df_salary_tech['country'].isin(lf)
df_salary_tech.loc[mask, 'country'] = 'US'

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_salary_tech['country'].value_counts()
# Out:
# country
# US                         3710
# canada                        5
# israel                        5
# united state of america       2
# unite states                  2
# australia                     2
# unitedstates                  2
# india                         2
# singapore                     2
# spain                         2
# brazil                        2
# united kingdom                2
# new zealand                   2
# poland                        2
# france                        2
# denmark                       2
# nigeria                       2
# uniyed states                 1
# america                       1
# puerto rico                   1
# united state                  1
# cuba                          1
# danmark                       1
# italy                         1
# international                 1
# united stated                 1
# remote (philippines)          1
# uruguay                       1
# mexico                        1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
mask = df_salary_tech['country'] == 'US'

df_salary_tech[mask].groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
#       2 mask = df_salary_tech['country'] == 'US'
#       3
# ----> 4 df_salary_tech[mask].groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
#
# File ~/Projects/ds-fall-2026/.venv/lib/python3.14/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# ...

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'].str.replace(',', ''), errors = "coerce")

df_salary_tech['salary']
# Out:
# 8        112000
# 43       187500
# 44       110000
# 46       144600
# 47       200850
#           ...
# 28044     60000
# 28051     35000
# 28052    144000
# 28058    109000
# 28060      1700
# Name: salary, Length: 3777, dtype: int64

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
mask = df_salary_tech['country'] == 'US'

df_salary_tech[mask].groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Florida                          28800  157457.232143  2600000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155224.893130   875000
# Washington                          72  151372.923077   950000
# New York                         14000  148157.669540   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  135018.880795  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# ...

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_tech['timestamp'] = pd.to_datetime(df_salary_tech['timestamp'])

mask = (df_salary_tech['country'] == 'US') & (df_salary_tech['timestamp'].dt.year.isin([2021, 2022, 2023]))
df_salary_recent = df_salary_tech[mask]

df_salary_recent.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155355.206422   875000
# Washington                          72  151521.952522   950000
# New York                         14000  148157.669540   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  134989.043189  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary = df_manager[df_manager['currency'] == 'USD']

lf = ['United States', 'USA', 'U.S.', 'United States of America', 'US']
mask = df_salary['country'].isin(lf)
df_salary.loc[mask, 'country'] = 'US'

df_salary['salary'] = pd.to_numeric(df_salary['salary'].str.replace(',', ''), errors = "coerce")

mask = df_salary['country'] == 'US'
df_salary_summary = df_salary[mask].groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)

df_salary_summary
# Out:
#                                                        min      mean     max
# state
# Indiana, Ohio                                       245000  245000.0  245000
# Colorado, Nevada                                    190000  190000.0  190000
# California, Montana                                 185000  185000.0  185000
# California, Texas                                   185000  185000.0  185000
# Alabama, District of Columbia                       156000  156000.0  156000
# ...                                                    ...       ...     ...
# Illinois, Kentucky                                   41000   41000.0   41000
# Delaware, Pennsylvania                               35000   35000.0   35000
# District of Columbia, Washington                     35000   35000.0   35000
# District of Columbia, Maryland, Pennsylvania, V...   27040   27040.0   27040
# Maryland, New York                                   14000   14000.0   14000
#
# [113 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
df_salary_summary.style.format('${:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_68f76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68f76_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_68f76_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_68f76_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68f76_level0_row0" class="row_heading level0 row0" >Indiana, Ohio</th>
#       <td id="T_68f76_row0_col0" class="data row0 col0" >$245,000.00</td>
#       <td id="T_68f76_row0_col1" class="data row0 col1" >$245,000.00</td>
#       <td id="T_68f76_row0_col2" class="data row0 col2" >$245,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
mask = (df_salary['country'] == 'US') & (~df_salary['state'].str.contains(',', na=False))
df_salary_single = df_salary[mask]

df_salary_single.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                         min           mean      max
# state
# California                0  115416.542344   875000
# Washington               72  107865.241088  1260000
# District of Columbia     40  107231.447339  1334782
# New York                 80  105591.720144  3000000
# Massachusetts          4100   98247.338996  1650000
# Connecticut               0   95868.565000  1900000
# Virginia                 57   94481.754986  1300000
# Illinois                  0   90219.231350  1100000
# Oregon                    0   89754.292115   320000
# Colorado                 65   89316.395018   630000
# Maryland                 58   89096.098790   323000
# Texas                     0   89092.663384  1200000
# New Jersey            14850   88784.956268   400000
# Utah                  18720   87845.978261   576000
# Delaware              35000   86526.285714   220000
# Georgia                   0   85978.928721   415000
# New Mexico              130   85342.759494   300000
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
df_salary_single.groupby('state')['salary'].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).sort_values('50%', ascending=False)
# Out:
#                        count           mean            std      min        5%  \
# state
# California            2338.0  115416.542344   63008.385938      0.0  42544.00
# Washington            1066.0  107865.241088   74500.888671     72.0  40000.00
# District of Columbia   883.0  107231.447339   90731.371535     40.0  48000.00
# New York              1951.0  105591.720144   87989.670813     80.0  41100.00
# Massachusetts         1354.0   98247.338996   63889.194414   4100.0  42416.90
# Connecticut            200.0   95868.565000  134440.012808      0.0  33957.50
# Maryland               496.0   89096.098790   40453.585657     58.0  39750.00
# Delaware                42.0   86526.285714   39139.097327  35000.0  41620.80
# Virginia               702.0   94481.754986   68505.213399     57.0  38214.00
# Oregon                 558.0   89754.292115   45882.185041      0.0  36000.00
# Illinois              1059.0   90219.231350   62255.884813      0.0  37360.00
# ...
