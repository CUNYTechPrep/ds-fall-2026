# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.14.2/lib/python3.14/site-packages (3.0.5)
# Requirement already satisfied: numpy in /usr/local/python/3.14.2/lib/python3.14/site-packages (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape[0]
# Out:
# 125

# %%
# Try to print or display it nicely.
print("Rows:", df_food.shape[0])
print("Columns:", df_food.shape[1])
# Out:
# Rows: 125
# Columns: 61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
pd.DataFrame(df_food.dtypes)
# Out:
#                         0
# GPA                   str
# Gender              int64
# breakfast           int64
# calories_chicken    int64
# calories_day      float64
# ...                   ...
# type_sports           str
# veggies_day         int64
# vitamins            int64
# waffle_calories     int64
# weight                str
#
# [61 rows x 1 columns]

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.
pd.DataFrame(df_food.dtypes, columns=["Data Type"])
# Out:
#                              Data Type
# GPA                                str
# Gender                           int64
# breakfast                        int64
# calories_chicken                 int64
# calories_day                   float64
# calories_scone                 float64
# coffee                           int64
# comfort_food                       str
# comfort_food_reasons               str
# comfort_food_reasons_coded     float64
# cook                           float64
# comfort_food_reasons_coded.1     int64
# cuisine                        float64
# diet_current                       str
# diet_current_coded               int64
# drink                          float64
# eating_changes                     str
# eating_changes_coded             int64
# eating_changes_coded1            int64
# eating_out                       int64
# employment                     float64
# ethnic_food                      int64
# exercise                       float64
# father_education               float64
# father_profession                  str
# fav_cuisine                        str
# fav_cuisine_coded                int64
# fav_food                       float64
# food_childhood                     str
# fries                            int64
# fruit_day                        int64
# grade_level                      int64
# greek_food                       int64
# healthy_feeling                  int64
# healthy_meal                       str
# ideal_diet                         str
# ideal_diet_coded                 int64
# income                         float64
# indian_food                      int64
# italian_food                     int64
# life_rewarding                 float64
# marital_status                 float64
# meals_dinner_friend                str
# mother_education               float64
# mother_profession                  str
# nutritional_check                int64
# on_off_campus                  float64
# parents_cook                     int64
# pay_meal_out                     int64
# persian_food                   float64
# self_perception_weight         float64
# soup                           float64
# sports                         float64
# thai_food                        int64
# tortilla_calories              float64
# turkey_calories                  int64
# type_sports                        str
# veggies_day                      int64
# vitamins                         int64
# waffle_calories                  int64
# weight                             str

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.
df_food_col_subset=df_food[["calories_day","weight","Gender"]]
df_food_col_subset.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %%
# Is there a second way to remove columns?
df_food_col_subset2 = df_food.drop(
    columns=df_food.columns.difference(["calories_day", "weight", "Gender"])
)

df_food_col_subset2.head()
# Out:
#    Gender  calories_day                    weight
# 0       2           NaN                       187
# 1       1           3.0                       155
# 2       1           4.0  I'm not answering this.
# 3       1           3.0             Not sure, 240
# 4       1           2.0                       190

# %%
# 🚀 Extra credit: What about a third way to remove columns?
df_food_col_subset3 = df_food.loc[:, ["calories_day", "weight", "Gender"]]

df_food_col_subset3.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food_col_subset.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.
pd.DataFrame(df_food_col_subset.isna().sum(), columns=["NaN Count"])
# Out:
#               NaN Count
# calories_day         19
# weight                2
# Gender                0

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.
nan_counts = df_food_col_subset \
    .isna() \
    .sum()

nan_counts
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.

df_food_col_subset.dropna(inplace=True)
df_food_col_subset.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂
df_food.isna().sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# fav_food                         2
# food_childhood                   1
# fries                            0
# fruit_day                        0
# grade_level                      0
# greek_food                       0
# healthy_feeling                  0
# healthy_meal                     1
# ideal_diet                       1
# ideal_diet_coded                 0
# income                           1
# indian_food                      0
# italian_food                     0
# life_rewarding                   1
# marital_status                   1
# meals_dinner_friend              3
# mother_education                 3
# mother_profession                2
# nutritional_check                0
# on_off_campus                    1
# parents_cook                     0
# pay_meal_out                     0
# persian_food                     1
# self_perception_weight           1
# soup                             1
# sports                           2
# thai_food                        0
# tortilla_calories                1
# turkey_calories                  0
# type_sports                     26
# veggies_day                      0
# vitamins                         0
# waffle_calories                  0
# weight                           2
# dtype: int64

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.
df_food_col_subset["weight"] = pd.to_numeric(
    df_food_col_subset["weight"], errors="coerce"
)

df_food_col_subset.dropna(inplace=True)
df_food_col_subset.dtypes
# Out:
# calories_day    float64
# weight          float64
# Gender            int64
# dtype: object

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_col_subset.to_csv("clean_food_data.csv", index=False)

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.
with open("clean_food_data.csv", "r") as file:
    for i in range(5):
        print(file.readline())
# Out:
# calories_day,weight,Gender
#
# 3.0,155.0,1
#
# 2.0,190.0,1
#
# 3.0,190.0,1
#
# 3.0,180.0,2

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.
salary_data_set_path = '../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'
df_salary = pd.read_csv(salary_data_set_path, sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_salary.shape[0]
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# If your job title needs additional context, please clarify here:                                                                                                                                                                            str
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)        str
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          float64
# Please indicate the currency                                                                                                                                                                                                                str
# If "Other," please indicate the currency here:                                                                                                                                                                                              str
# If your income needs additional context, please provide it here:                                                                                                                                                                            str
# What country do you work in?                                                                                                                                                                                                                str
# If you're in the U.S., what state do you work in?                                                                                                                                                                                           str
# What city do you work in?                                                                                                                                                                                                                   str
# How many years of professional work experience do you have overall?                                                                                                                                                                         str
# How many years of professional work experience do you have in your field?                                                                                                                                                                   str
# What is your highest level of education completed?                                                                                                                                                                                          str
# What is your gender?                                                                                                                                                                                                                        str
# What is your race? (Choose all that apply.)                                                                                                                                                                                                 str
# dtype: object

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.rename(columns=dict(zip(
    df_salary.columns,
    [
        "timestamp",
        "age",
        "industry",
        "title",
        "title_context",
        "salary",
        "additional_compensation",
        "currency",
        "other_currency",
        "salary_context",
        "country",
        "state",
        "city",
        "total_yoe",
        "field_yoe",
        "highest_education_completed",
        "gender",
        "race"
    ]
)), inplace=True)
df_salary.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
#        'additional_compensation', 'currency', 'other_currency',
#        'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe',
#        'highest_education_completed', 'gender', 'race'],
#       dtype='str')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary["industry"].value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.
df_salary_tech = df_salary[df_salary["industry"] == "Computing or Tech"]

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.

df_salary_tech.shape[0]
# Out:
# 4699

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!
df_salary_tech = df_salary_tech[df_salary_tech["currency"] == "USD"]

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_tech["country"].value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.

df_salary_tech.replace(
    {"country": {
        "United States": "US",
        "USA": "US",
        "US": "US",
        "U.S.": "US",
        "United States of America": "US"
    }},
    inplace=True
)
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# 46                           Mobile developer                           NaN
# 47                    Product Design Director                           NaN
# ...                                       ...                           ...
# 28044         Research Data Analyst Associate                           NaN
# 28051                    Junior data analyst                            NaN
# 28052  Senior Global Public Relations Manager                           NaN
# 28058                       Systems Architect                           NaN
# 28060                                      IT                           NaN
#
#         salary  additional_compensation currency other_currency  \
# 8      112,000                  10000.0      USD            NaN
# 43     187,500                   5000.0      USD            NaN
# 44     110,000                  20000.0      USD            NaN
# 46     144,600                   2500.0      USD            NaN
# 47     200,850                  40000.0      USD            NaN
# ...        ...                      ...      ...            ...
# 28044    60000                      0.0      USD            NaN
# 28051    35000                  15000.0      USD            NaN
# 28052   144000                  15000.0      USD            NaN
# 28058   109000                      NaN      USD            NaN
# 28060     1700                     10.0      USD            NaN
#
#                       salary_context country           state  \
# 8                                NaN      US        Missouri
# 43                               NaN      US    Pennsylvania
# 44     Around 20,000 a year in stock      US        Virginia
# 46                               NaN      US   Massachusetts
# 47                               NaN      US  North Carolina
# ...                              ...     ...             ...
# 28044                            NaN      US        Illinois
# 28051                            NaN     Usa         Alabama
# 28052                            NaN     Usa   Massachusetts
# 28058                            NaN      US         Georgia
# 28060                            NaN   Burma             NaN
#
#                                                city      total_yoe  \
# 8                                         St. Louis  21 - 30 years
# 43                                       Pittsburgh   8 - 10 years
# 44                                    Arlington, VA   8 - 10 years
# 46                                           Boston      5-7 years
# 47                                      Chapel Hill  11 - 20 years
# ...                                             ...            ...
# 28044                                      Evanston    2 - 4 years
# 28051                                      Alabama     2 - 4 years
# 28052  Boise-but remote. Company located in Boston    8 - 10 years
# 28058                                       Atlanta      5-7 years
# 28060                                        Yangon    2 - 4 years
#
#             field_yoe highest_education_completed gender  \
# 8       21 - 30 years              College degree  Woman
# 43          5-7 years              College degree  Woman
# 44       8 - 10 years             Master's degree    Man
# 46          5-7 years                         PhD  Woman
# 47      11 - 20 years              College degree  Woman
# ...               ...                         ...    ...
# 28044  1 year or less              College degree  Woman
# 28051     2 - 4 years              College degree  Woman
# 28052    8 - 10 years             Master's degree  Woman
# 28058       5-7 years              College degree    Man
# 28060  1 year or less                Some college    Man
#
#                             race
# 8                          White
# 43                         White
# 44                         White
# 46                         White
# 47                         White
# ...                          ...
# 28044                      White
# 28051  Black or African American
# 28052                      White
# 28058                      White
# 28060    Asian or Asian American
#
# [3777 rows x 18 columns]

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech["country"].value_counts()
# Out:
# country
# US                           3408
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_tech.loc[
    df_salary_tech["country"]
        .str.lower()
        .str.replace(".", "", regex=False)
        .str.replace(" ", "", regex=False)
        .isin(["us", "usa", "unitedstates", "unitedstatesofamerica"]),
    "country"
] = "US"

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_tech["country"].value_counts()
# Out:
# country
# US                         3712
# Israel                        5
# Canada                        4
# United State of America       2
# Unite States                  2
# Australia                     2
# India                         2
# Spain                         2
# Brazil                        2
# United Kingdom                2
# New Zealand                   2
# Poland                        2
# France                        2
# Uniyed states                 1
# America                       1
# Puerto Rico                   1
# United State                  1
# Cuba                          1
# Danmark                       1
# Italy                         1
# International                 1
# United Stated                 1
# Remote (philippines)          1
# Singapore                     1
# Uruguay                       1
# Mexico                        1
# Canada                        1
# United Stateds                1
# ISA                           1
# singapore                     1
# Pakistan                      1
# Netherlands                   1
# China                         1
# San Francisco                 1
# Romania                       1
# Japan                         1
# United Stares                 1
# Australian                    1
# Denmark                       1
# Jamaica                       1
# Unites States                 1
# Thailand                      1
# Colombia                      1
# denmark                       1
# Ghana                         1
# Nigeria                       1
# ss                            1
# Nigeria                       1
# Burma                         1
# Name: count, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_tech.groupby("state")["salary"].agg(["min", "mean", "max"]).sort_values("mean", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
# ----> 2 df_salary_tech.groupby("state")["salary"].agg(["min", "mean", "max"]).sort_values("mean", ascending=False)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     520     for idx, (name, func) in enumerate(arg):
#     521         key = base.OutputKey(label=name, position=idx)
# --> 522         results[key] = self.aggregate(func, *args, **kwargs)
#     524 if any(isinstance(x, DataFrame) for x in results.values()):
#     525     from pandas import concat
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/internals/managers.py:2295, in SingleBlockManager.grouped_reduce(self, func)
#    2293 def grouped_reduce(self, func):
#    2294     arr = self.array
# -> 2295     res = func(arr)
#    2296     index = default_index(len(res))
#    2298     mgr = type(self).from_array(res, index)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/arrays/base.py:2808, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2794 if isinstance(self.dtype, StringDtype):
#    2795     # StringArray
#    2796     if op.how in [
#    2797         "prod",
#    2798         "mean",
#    (...)   2806         "kurt",
#    2807     ]:
# -> 2808         raise TypeError(
#    2809             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2810         )
#    2811     if op.how not in ["any", "all"]:
#    2812         # Fail early to avoid conversion to object
#    2813         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary_tech["salary"] = pd.to_numeric(
    df_salary_tech["salary"].str.replace(",", ""),
    errors="coerce"
)

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_tech.groupby("state")["salary"].agg(
    ["min", "mean", "max"]
).sort_values("mean", ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Florida                          28800  157457.232143  2600000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  154857.215478   875000
# Washington                          72  151423.670588   950000
# New York                         14000  148054.638968   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  135213.537954  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# New Jersey                       40000  128802.475000   603000
# Connecticut                      62400  128375.000000   270000
# Virginia                         43642  127706.355932   450000
# Colorado                         45000  127240.006849   630000
# Massachusetts, Rhode Island     125000  125000.000000   125000
# Oregon                           16200  124297.800000   320000
# Georgia, Washington             123000  123000.000000   123000
# West Virginia                   116500  120500.000000   125000
# Illinois                         13500  119268.242604   315000
# Georgia                          29120  117893.098765   250000
# Maryland                         51260  117862.370370   205000
# Louisiana, Washington           117000  117000.000000   117000
# Delaware                         63000  116600.000000   169000
# South Dakota                     86000  115333.333333   150000
# Wisconsin                            1  114268.000000   920000
# Texas                            10700  113909.713004   280000
# Tennessee                        36550  112847.058824   240000
# Alaska                           67000  112500.000000   158000
# Vermont                          65000  111781.250000   200000
# Pennsylvania                     32000  111623.123894   237000
# Idaho                            50000  111527.692308   312000
# Rhode Island                     76000  111491.666667   180000
# District of Columbia, Virginia  109200  109200.000000   109200
# Minnesota                        34000  106752.793103   230000
# Ohio                             32240  106338.835821   954000
# Utah                             33280  105836.479167   245000
# North Carolina                   29000  105035.441441   260000
# New York, Texas                 105000  105000.000000   105000
# Massachusetts, New Hampshire    105000  105000.000000   105000
# Arizona                          35000  104491.891892   210000
# Maine                            50000  103571.428571   173000
# South Carolina                   40000  102111.111111   205000
# Iowa                             47840   99729.736842   160000
# Kansas                           41500   99565.052632   167000
# North Dakota                     45760   97880.000000   150000
# Michigan                         36800   96855.363636   235000
# Montana                          65000   95500.000000   145000
# Missouri                            80   95317.652174   200000
# New Hampshire                       55   95179.705882   193000
# Arizona, Utah                    95000   95000.000000    95000
# Mississippi                      94000   94000.000000    94000
# Alabama                          29120   92510.000000   350000
# Kentucky                         39000   92375.000000   170000
# Nebraska                         43000   90975.294118   166400
# Indiana                          15000   88566.647059   200000
# Oklahoma                         28536   87929.500000   180000
# Louisiana                        35360   83269.090909   150000
# Massachusetts, Pennsylvania      83000   83000.000000    83000
# California, Maryland             81500   81500.000000    81500
# Arkansas                             4   74257.000000   144000
# Alabama, Montana                 72000   72000.000000    72000

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech["timestamp"] = pd.to_datetime(df_salary_tech["timestamp"])

df_salary_tech_years = df_salary_tech[
    df_salary_tech["timestamp"].dt.year.isin([2021, 2022, 2023])
]

df_salary_tech_years.groupby("state")["salary"].agg(
    ["min", "mean", "max"]
).sort_values("mean", ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  154986.177812   875000
# Washington                          72  151571.970501   950000
# New York                         14000  148054.638968   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  135184.443709  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# New Jersey                       40000  128802.475000   603000
# Connecticut                      62400  128375.000000   270000
# Virginia                         43642  127706.355932   450000
# Colorado                         45000  127240.006849   630000
# Massachusetts, Rhode Island     125000  125000.000000   125000
# Oregon                           16200  124297.800000   320000
# Georgia, Washington             123000  123000.000000   123000
# West Virginia                   116500  120500.000000   125000
# Illinois                         13500  119621.029762   315000
# Georgia                          29120  118004.262500   250000
# Maryland                         51260  117862.370370   205000
# Louisiana, Washington           117000  117000.000000   117000
# Delaware                         63000  116600.000000   169000
# South Dakota                     86000  115333.333333   150000
# Wisconsin                            1  114268.000000   920000
# Texas                            10700  113909.713004   280000
# Florida                          28800  113047.363636   400000
# Tennessee                        36550  112847.058824   240000
# Alaska                           67000  112500.000000   158000
# Vermont                          65000  111781.250000   200000
# Pennsylvania                     32000  111623.123894   237000
# Idaho                            50000  111527.692308   312000
# Rhode Island                     76000  111491.666667   180000
# South Carolina                   40000  109875.000000   205000
# District of Columbia, Virginia  109200  109200.000000   109200
# Minnesota                        34000  107063.872093   230000
# Ohio                             32240  106338.835821   954000
# Utah                             33280  105836.479167   245000
# New York, Texas                 105000  105000.000000   105000
# Massachusetts, New Hampshire    105000  105000.000000   105000
# North Carolina                   29000  104944.854545   260000
# Arizona                          35000  104491.891892   210000
# Maine                            50000  103571.428571   173000
# Iowa                             47840   99729.736842   160000
# Kansas                           41500   99565.052632   167000
# North Dakota                     45760   97880.000000   150000
# Alabama                          29120   97738.181818   350000
# Michigan                         36800   96855.363636   235000
# Montana                          65000   95500.000000   145000
# Missouri                            80   95317.652174   200000
# New Hampshire                       55   95179.705882   193000
# Arizona, Utah                    95000   95000.000000    95000
# Mississippi                      94000   94000.000000    94000
# Kentucky                         39000   92375.000000   170000
# Nebraska                         43000   90975.294118   166400
# Indiana                          15000   88566.647059   200000
# Oklahoma                         28536   87929.500000   180000
# Louisiana                        35360   83269.090909   150000
# Massachusetts, Pennsylvania      83000   83000.000000    83000
# Arkansas                         55000   81682.300000   144000
# California, Maryland             81500   81500.000000    81500
# Alabama, Montana                 72000   72000.000000    72000

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
# Keep only salaries paid in USD
df_salary_bonus = df_salary[df_salary["currency"] == "USD"].copy()

# Convert salary from text to numeric
df_salary_bonus["salary"] = pd.to_numeric(
    df_salary_bonus["salary"].str.replace(",", ""),
    errors="coerce"
)

# Generate minimum, mean, and maximum salary by state
df_salary_bonus.groupby("state")["salary"].agg(
    ["min", "mean", "max"]
).sort_values("mean", ascending=False)
# Out:
#                                                         min          mean  \
# state
# Alabama, South Carolina                             5000000  5.000000e+06
# Michigan, Texas, Washington                          340000  3.400000e+05
# Indiana, Ohio                                        245000  2.450000e+05
# Alaska                                                27040  2.322751e+05
# Colorado, Nevada                                     190000  1.900000e+05
# ...                                                     ...           ...
# District of Columbia, Washington                      35000  3.500000e+04
# Alabama, California                                   29120  2.912000e+04
# District of Columbia, Maryland, Pennsylvania, V...    27040  2.704000e+04
# Maryland, New York                                    14000  1.400000e+04
# Alabama, Alaska, Arizona                                 15  1.500000e+01
#
#                                                          max
# state
# Alabama, South Carolina                              5000000
# Michigan, Texas, Washington                           340000
# Indiana, Ohio                                         245000
# Alaska                                              10000000
# Colorado, Nevada                                      190000
# ...                                                      ...
# District of Columbia, Washington                       35000
# Alabama, California                                    29120
# District of Columbia, Maryland, Pennsylvania, V...     27040
# Maryland, New York                                     14000
# Alabama, Alaska, Arizona                                  15
#
# [133 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
df_salary_bonus.groupby("state")["salary"].agg(
    ["min", "mean", "max"]
).sort_values("mean", ascending=False).style.format("${:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_93f75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93f75_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_93f75_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_93f75_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93f75_level0_row0" class="row_heading level0 row0" >Alabama, South Carolina</th>
#       <td id="T_93f75_row0_col0" class="data row0 col0" >$5,000,000.00</td>
#       <td id="T_93f75_row0_col1" class="data row0 col1" >$5,000,000.00</td>
#       <td id="T_93f75_row0_col2" class="data row0 col2" >$5,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row1" class="row_heading level0 row1" >Michigan, Texas, Washington</th>
#       <td id="T_93f75_row1_col0" class="data row1 col0" >$340,000.00</td>
#       <td id="T_93f75_row1_col1" class="data row1 col1" >$340,000.00</td>
#       <td id="T_93f75_row1_col2" class="data row1 col2" >$340,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row2" class="row_heading level0 row2" >Indiana, Ohio</th>
#       <td id="T_93f75_row2_col0" class="data row2 col0" >$245,000.00</td>
#       <td id="T_93f75_row2_col1" class="data row2 col1" >$245,000.00</td>
#       <td id="T_93f75_row2_col2" class="data row2 col2" >$245,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row3" class="row_heading level0 row3" >Alaska</th>
#       <td id="T_93f75_row3_col0" class="data row3 col0" >$27,040.00</td>
#       <td id="T_93f75_row3_col1" class="data row3 col1" >$232,275.08</td>
#       <td id="T_93f75_row3_col2" class="data row3 col2" >$10,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row4" class="row_heading level0 row4" >Colorado, Nevada</th>
#       <td id="T_93f75_row4_col0" class="data row4 col0" >$190,000.00</td>
#       <td id="T_93f75_row4_col1" class="data row4 col1" >$190,000.00</td>
#       <td id="T_93f75_row4_col2" class="data row4 col2" >$190,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row5" class="row_heading level0 row5" >California, Montana</th>
#       <td id="T_93f75_row5_col0" class="data row5 col0" >$185,000.00</td>
#       <td id="T_93f75_row5_col1" class="data row5 col1" >$185,000.00</td>
#       <td id="T_93f75_row5_col2" class="data row5 col2" >$185,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row6" class="row_heading level0 row6" >California, Texas</th>
#       <td id="T_93f75_row6_col0" class="data row6 col0" >$185,000.00</td>
#       <td id="T_93f75_row6_col1" class="data row6 col1" >$185,000.00</td>
#       <td id="T_93f75_row6_col2" class="data row6 col2" >$185,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row7" class="row_heading level0 row7" >Georgia, Massachusetts</th>
#       <td id="T_93f75_row7_col0" class="data row7 col0" >$175,000.00</td>
#       <td id="T_93f75_row7_col1" class="data row7 col1" >$175,000.00</td>
#       <td id="T_93f75_row7_col2" class="data row7 col2" >$175,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row8" class="row_heading level0 row8" >Alabama, District of Columbia</th>
#       <td id="T_93f75_row8_col0" class="data row8 col0" >$156,000.00</td>
#       <td id="T_93f75_row8_col1" class="data row8 col1" >$156,000.00</td>
#       <td id="T_93f75_row8_col2" class="data row8 col2" >$156,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row9" class="row_heading level0 row9" >Arizona, California</th>
#       <td id="T_93f75_row9_col0" class="data row9 col0" >$90,000.00</td>
#       <td id="T_93f75_row9_col1" class="data row9 col1" >$152,500.00</td>
#       <td id="T_93f75_row9_col2" class="data row9 col2" >$215,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row10" class="row_heading level0 row10" >California, Oregon</th>
#       <td id="T_93f75_row10_col0" class="data row10 col0" >$93,000.00</td>
#       <td id="T_93f75_row10_col1" class="data row10 col1" >$148,250.00</td>
#       <td id="T_93f75_row10_col2" class="data row10 col2" >$200,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row11" class="row_heading level0 row11" >New Jersey, New York</th>
#       <td id="T_93f75_row11_col0" class="data row11 col0" >$135,000.00</td>
#       <td id="T_93f75_row11_col1" class="data row11 col1" >$146,200.00</td>
#       <td id="T_93f75_row11_col2" class="data row11 col2" >$170,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row12" class="row_heading level0 row12" >Ohio, Wyoming</th>
#       <td id="T_93f75_row12_col0" class="data row12 col0" >$140,000.00</td>
#       <td id="T_93f75_row12_col1" class="data row12 col1" >$140,000.00</td>
#       <td id="T_93f75_row12_col2" class="data row12 col2" >$140,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row13" class="row_heading level0 row13" >Indiana, Massachusetts</th>
#       <td id="T_93f75_row13_col0" class="data row13 col0" >$132,000.00</td>
#       <td id="T_93f75_row13_col1" class="data row13 col1" >$132,000.00</td>
#       <td id="T_93f75_row13_col2" class="data row13 col2" >$132,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row14" class="row_heading level0 row14" >Illinois, Wisconsin</th>
#       <td id="T_93f75_row14_col0" class="data row14 col0" >$130,704.00</td>
#       <td id="T_93f75_row14_col1" class="data row14 col1" >$130,704.00</td>
#       <td id="T_93f75_row14_col2" class="data row14 col2" >$130,704.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row15" class="row_heading level0 row15" >California, Colorado</th>
#       <td id="T_93f75_row15_col0" class="data row15 col0" >$85,000.00</td>
#       <td id="T_93f75_row15_col1" class="data row15 col1" >$130,500.00</td>
#       <td id="T_93f75_row15_col2" class="data row15 col2" >$176,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row16" class="row_heading level0 row16" >California, District of Columbia, Illinois, Iowa, Maryland, Minnesota</th>
#       <td id="T_93f75_row16_col0" class="data row16 col0" >$130,000.00</td>
#       <td id="T_93f75_row16_col1" class="data row16 col1" >$130,000.00</td>
#       <td id="T_93f75_row16_col2" class="data row16 col2" >$130,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row17" class="row_heading level0 row17" >Utah, Vermont</th>
#       <td id="T_93f75_row17_col0" class="data row17 col0" >$130,000.00</td>
#       <td id="T_93f75_row17_col1" class="data row17 col1" >$130,000.00</td>
#       <td id="T_93f75_row17_col2" class="data row17 col2" >$130,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row18" class="row_heading level0 row18" >Alabama, Minnesota, Nevada</th>
#       <td id="T_93f75_row18_col0" class="data row18 col0" >$130,000.00</td>
#       <td id="T_93f75_row18_col1" class="data row18 col1" >$130,000.00</td>
#       <td id="T_93f75_row18_col2" class="data row18 col2" >$130,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row19" class="row_heading level0 row19" >Arkansas, Idaho, Kansas, Louisiana, Michigan, Mississippi, Nevada, New York, South Carolina, Tennessee, Washington</th>
#       <td id="T_93f75_row19_col0" class="data row19 col0" >$125,000.00</td>
#       <td id="T_93f75_row19_col1" class="data row19 col1" >$125,000.00</td>
#       <td id="T_93f75_row19_col2" class="data row19 col2" >$125,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row20" class="row_heading level0 row20" >Massachusetts, Rhode Island</th>
#       <td id="T_93f75_row20_col0" class="data row20 col0" >$125,000.00</td>
#       <td id="T_93f75_row20_col1" class="data row20 col1" >$125,000.00</td>
#       <td id="T_93f75_row20_col2" class="data row20 col2" >$125,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_93f75_level0_row21" class="row_heading level0 row21" >Georgia, Washington</th>
#       <td id="T_93f75_row21_col0" class="data row21 col0" >$123

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
