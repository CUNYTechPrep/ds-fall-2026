# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: c:\Users\axylo\.pyenv\pyenv-win\versions\3.12.10\python.exe -m pip install --upgrade pip

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)

df_food # there's 125 rows, 61 columns
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
# Try to print or display it nicely.

df_food_shape = df_food.shape # this is a tuple 

rows, cols = df_food_shape

print("Rows: ", rows)
print("Columns: ", cols)
# Out:
# Rows:  125
# Columns:  61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

df_food.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.

df_food.iloc[0:100]
# Out:
#            GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0          2.4       2          1               430           NaN
# 1        3.654       1          1               610           3.0
# 2          3.3       1          1               720           4.0
# 3          3.2       1          1               430           3.0
# 4          3.5       1          1               720           2.0
# 5         2.25       1          1               610           3.0
# 6          3.8       2          1               610           3.0
# 7          3.3       1          1               720           3.0
# 8          3.3       1          1               430           NaN
# 9          3.3       1          1               430           3.0
# 10         3.5       1          1               610           3.0
# 11       3.904       1          1               720           4.0
# 12         3.4       2          1               430           3.0
# ...

# %%
df_food.iloc[100:rows]
# Out:
#          GPA  Gender  breakfast  calories_chicken  calories_day  \
# 100      3.5       1          1               610           3.0
# 101      3.4       1          1               610           NaN
# 102      NaN       1          1               610           4.0
# 103      3.7       1          1               610           3.0
# 104  Unknown       1          1               720           3.0
# 105        3       1          1               720           3.0
# 106        3       1          1               430           3.0
# 107      3.8       1          1               430           3.0
# 108      3.8       1          1               430           2.0
# 109      3.4       1          1               610           3.0
# 110      3.7       1          1               610           3.0
# 111      2.9       2          1               265           2.0
# 112      3.9       1          1               610           4.0
# 113      3.6       1          1               430           2.0
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.

df_food_col_subset = df_food[["calories_day", "weight", "Gender"]]

df_food_col_subset
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %%
# Is there a second way to remove columns?

# idea from: https://stackoverflow.com/questions/11285613/selecting-multiple-columns-in-a-pandas-dataframe

df_food_col_subset = df_food.loc[:, ["calories_day", "weight", "Gender"]]

df_food_col_subset
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %%
# 🚀 Extra credit: What about a third way to remove columns?
df_food_col_subset = df_food.loc[:, df_food.columns.isin(["calories_day", "weight", "Gender"])]

df_food_col_subset
# Out:
#      Gender  calories_day                    weight
# 0         2           NaN                       187
# 1         1           3.0                       155
# 2         1           4.0  I'm not answering this.
# 3         1           3.0             Not sure, 240
# 4         1           2.0                       190
# ..      ...           ...                       ...
# 120       1           4.0                       156
# 121       1           2.0                       180
# 122       1           NaN                       120
# 123       2           4.0                       135
# 124       1           NaN                       135
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

print(df_food.isna().sum())
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             2
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# ...

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

df_food_na_counts = pd.DataFrame(df_food.isna().sum(), columns=["NaN Count"])
print(df_food_na_counts)
# Out:
#                               NaN Count
# GPA                                   2
# Gender                                0
# breakfast                             0
# calories_chicken                      0
# calories_day                         19
# calories_scone                        1
# coffee                                0
# comfort_food                          1
# comfort_food_reasons                  2
# comfort_food_reasons_coded           19
# cook                                  3
# comfort_food_reasons_coded.1          0
# cuisine                              17
# diet_current                          1
# diet_current_coded                    0
# drink                                 2
# eating_changes                        3
# eating_changes_coded                  0
# eating_changes_coded1                 0
# eating_out                            0
# employment                            9
# ethnic_food                           0
# ...

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

df_food_na_counts = \
    pd.DataFrame(df_food.isna().sum(), 
                 columns=["NaN Count"])
print(df_food_na_counts)
# Out:
#                               NaN Count
# GPA                                   2
# Gender                                0
# breakfast                             0
# calories_chicken                      0
# calories_day                         19
# calories_scone                        1
# coffee                                0
# comfort_food                          1
# comfort_food_reasons                  2
# comfort_food_reasons_coded           19
# cook                                  3
# comfort_food_reasons_coded.1          0
# cuisine                              17
# diet_current                          1
# diet_current_coded                    0
# drink                                 2
# eating_changes                        3
# eating_changes_coded                  0
# eating_changes_coded1                 0
# eating_out                            0
# employment                            9
# ethnic_food                           0
# ...

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.

df_food.dropna(inplace=True)
print(df_food)
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# ...

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂

df_food # it affected the original
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# ...

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.

for x in df_food.index:
  gpa_value = df_food.loc[x, "GPA"]
  try:
      val = float(gpa_value)
  except ValueError:
      df_food.drop(x, inplace=True)
      print(x, "Invalid float")

df_food # it affected the original
# Out:
# 73 Invalid float
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# 6      3.8       2          1               610           3.0           420.0
# 7      3.3       1          1               720           3.0           420.0
# 9      3.3       1          1               430           3.0           315.0
# 10     3.5       1          1               610           3.0           980.0
# 11   3.904       1          1               720           4.0           420.0
# 12     3.4       2          1               430           3.0           420.0
# 13     3.6       1          1               610           3.0           420.0
# 14     3.1       2          1               610           3.0           420.0
# ...

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food.to_csv('../data/food_coded_cleaned.csv', index=False)

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.

plain_text_lines = open('../data/food_coded_cleaned.csv').readlines()
for i in range(5):
    print(plain_text_lines[i])
# Out:
# GPA,Gender,breakfast,calories_chicken,calories_day,calories_scone,coffee,comfort_food,comfort_food_reasons,comfort_food_reasons_coded,cook,comfort_food_reasons_coded.1,cuisine,diet_current,diet_current_coded,drink,eating_changes,eating_changes_coded,eating_changes_coded1,eating_out,employment,ethnic_food,exercise,father_education,father_profession,fav_cuisine,fav_cuisine_coded,fav_food,food_childhood,fries,fruit_day,grade_level,greek_food,healthy_feeling,healthy_meal,ideal_diet,ideal_diet_coded,income,indian_food,italian_food,life_rewarding,marital_status,meals_dinner_friend,mother_education,mother_profession,nutritional_check,on_off_campus,parents_cook,pay_meal_out,persian_food,self_perception_weight,soup,sports,thai_food,tortilla_calories,turkey_calories,type_sports,veggies_day,vitamins,waffle_calories,weight
#
# ...

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.

df_salary = pd.read_csv('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary_col = df_salary.columns
for col in df_salary_col:
    print(col, "|", type(col))
# Out:
# Timestamp | <class 'str'>
# How old are you? | <class 'str'>
# What industry do you work in? | <class 'str'>
# Job title | <class 'str'>
# If your job title needs additional context, please clarify here: | <class 'str'>
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.) | <class 'str'>
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits. | <class 'str'>
# Please indicate the currency | <class 'str'>
# If "Other," please indicate the currency here:  | <class 'str'>
# If your income needs additional context, please provide it here: | <class 'str'>
# What country do you work in? | <class 'str'>
# If you're in the U.S., what state do you work in? | <class 'str'>
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.rename(columns={
    "Timestamp":"timestamp",
    "How old are you?":"age",
    "What industry do you work in?":"industry",
    "Job title":"title",
    "If your job title needs additional context, please clarify here:":"title_context",
    "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)":"salary",
    "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.":"additional_compensation",
    "Please indicate the currency":"currency",
    "If \"Other,\" please indicate the currency here: ":"other_currency",
    "If your income needs additional context, please provide it here:":"salary_context",
    "What country do you work in?":"country",
    "If you're in the U.S., what state do you work in?":"state",
    "What city do you work in?":"city",
    "How many years of professional work experience do you have overall?":"total_yoe",
    "How many years of professional work experience do you have in your field?":"field_yoe",
    "What is your highest level of education completed?":"highest_education_completed",
    "What is your gender?":"gender",
    "What is your race? (Choose all that apply.)":"race"
}, inplace=True)

df_salary.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
#        'additional_compensation', 'currency', 'other_currency',
#        'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe',
#        'highest_education_completed', 'gender', 'race'],
#       dtype='object')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_salary["industry"].value_counts()
# 4699 corresponds
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.

df_salary_filtered = df_salary[df_salary["industry"] == "Computing or Tech"]
print(df_salary_filtered)
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.

df_salary_filtered.shape
# Out:
# (4699, 18)

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!

df_salary_filtered = df_salary[df_salary["industry"] == "Computing or Tech"]
print(df_salary_filtered)
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_filtered["country"].value_counts()
# Out:
# country
# United States     1576
# USA               1222
# US                 413
# Canada             227
# United Kingdom     145
#                   ...
# Nigeria              1
# ss                   1
# ibdia                1
# Nigeria              1
# Burma                1
# Name: count, Length: 145, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.

first_5_values = df_salary["country"].value_counts().index[:6].tolist()

df_salary["country"] = df_salary["country"].replace(first_5_values, "US")

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary["country"].value_counts()
# Out:
# country
# US                           22353
# UK                             574
# United Kingdom                 547
# USA                            468
# Usa                            448
#                              ...
# Aotearoa New Zealand             1
# U.S.A                            1
# United States of American        1
# ENGLAND                          1
# Canadá                           1
# Name: count, Length: 374, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

salary_stats_by_state = df_salary.groupby("state")["salary"].agg(['min', 'mean', 'max'])
print(salary_stats_by_state)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\axylo\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\axylo\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\axylo\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary["salary"] = pd.to_numeric(
    df_salary["salary"]
    .astype(str)
    .str.replace(r'[,]', '', regex=True)  # no more ,
    .str.strip(),                         
    errors='coerce'
)

salary_stats_by_state = df_salary.groupby("state")["salary"].agg(['min', 'mean', 'max'])
print(salary_stats_by_state)
# Out:
#                                   min           mean      max
# state
# Alabama                             0   98178.475410  3600000
# Alabama, Alaska, Arizona           15      15.000000       15
# Alabama, California             29120   29120.000000    29120
# Alabama, District of Columbia  156000  156000.000000   156000
# Alabama, Kansas                 64197   64197.000000    64197
# ...                               ...            ...      ...
# Virginia                           57   94679.388041  1300000
# Washington                         72  107803.852196  1260000
# West Virginia                       0   59162.928571   125000
# Wisconsin                           1   76351.454158   920000
# Wyoming                         29000   58089.291667   140000
#
# [134 rows x 3 columns]

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

df_salary["salary"] = pd.to_numeric(
    df_salary["salary"]
    .astype(str)
    .str.replace(r'[,]', '', regex=True)  # no more ,
    .str.strip(),                         
    errors='coerce'
)

salary_stats_by_state = df_salary.groupby("state")["salary"].agg(['min', 'mean', 'max'])
print(salary_stats_by_state)
# Out:
#                                   min           mean      max
# state
# Alabama                             0   98178.475410  3600000
# Alabama, Alaska, Arizona           15      15.000000       15
# Alabama, California             29120   29120.000000    29120
# Alabama, District of Columbia  156000  156000.000000   156000
# Alabama, Kansas                 64197   64197.000000    64197
# ...                               ...            ...      ...
# Virginia                           57   94679.388041  1300000
# Washington                         72  107803.852196  1260000
# West Virginia                       0   59162.928571   125000
# Wisconsin                           1   76351.454158   920000
# Wyoming                         29000   58089.291667   140000
#
# [134 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_years_filtered = df_salary[df_salary["timestamp"].str.contains("2021|2022|2023", na=False)]

salary_stats_by_state_filtered = df_salary_years_filtered.groupby("state")["salary"].agg(['min', 'mean', 'max'])
print(salary_stats_by_state_filtered)
# Out:
#                                   min           mean      max
# state
# Alabama                             0  100565.153846  3600000
# Alabama, California             29120   29120.000000    29120
# Alabama, District of Columbia  156000  156000.000000   156000
# Alabama, Kansas                 64197   64197.000000    64197
# Alabama, Minnesota, Nevada     130000  130000.000000   130000
# ...                               ...            ...      ...
# Virginia                           57   94679.388041  1300000
# Washington                         72  107809.476754  1260000
# West Virginia                       0   59162.928571   125000
# Wisconsin                           1   76351.454158   920000
# Wyoming                         29000   58089.291667   140000
#
# [131 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
