# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import numpy as np
import pandas as pd

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
len(df_food)
# Out:
# 125

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
# Out:
# GPA                     str
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports             str
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight                  str
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food = df_food[['calories_day', 'weight', 'Gender']]
df_food
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

df_food = df_food.dropna()
df_food
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food['weight'] = pd.to_numeric(df_food['weight'], errors='coerce')
df_food = df_food.dropna()
df_food
# Out:
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food.to_csv('cleaned_food_data.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep='\t')
df_salary
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
len(df_salary)
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = [
    'timestamp',
    'age',
    'industry',
    'title',
    'title_context',
    'salary',
    'additional_compensation',
    'currency',
    'other_currency',
    'salary_context',
    'country',
    'state',
    'city',
    'total_yoe',
    'field_yoe',
    'highest_education_completed',
    'gender',
    'race'
]
df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary["industry"].value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech["industry"].value_counts()
# Out:
# industry
# Computing or Tech    4699
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_usd = df_salary_tech[df_salary_tech['currency'] == "USD"]
df_salary_usd.head()
# Out:
#              timestamp    age           industry                        title  \
# 8   4/27/2021 11:03:01  45-54  Computing or Tech              Systems Analyst
# 43  4/27/2021 11:04:04  25-34  Computing or Tech  Principal Software Engineer
# 44  4/27/2021 11:04:04  25-34  Computing or Tech         Intelligence Analyst
# 46  4/27/2021 11:04:07  35-44  Computing or Tech             Mobile developer
# 47  4/27/2021 11:04:09  35-44  Computing or Tech      Product Design Director
#
#                    title_context   salary  additional_compensation currency  \
# 8   Data developer/ETL Developer  112,000                  10000.0      USD
# 43                           NaN  187,500                   5000.0      USD
# 44                           NaN  110,000                  20000.0      USD
# 46                           NaN  144,600                   2500.0      USD
# 47                           NaN  200,850                  40000.0      USD
#
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_usd['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Ghana                          1
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
df_salary_usd['country'] = df_salary_usd['country'].replace(["United States of America", "USA", "US", "U.S.", "United States"], "US")
df_salary_usd
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_usd["country"].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Ghana                1
# Nigeria              1
# ss                   1
# Nigeria              1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_usd['country'] = df_salary_usd['country'].str.strip().str.lower()
df_salary_usd['country'] = df_salary_usd['country'].replace(['us', 'usa', 'united states', 'united states of america', 'u.s.a.', 'u.s.'], 'US')

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_usd['country'].value_counts()
# Out:
# country
# US                         3705
# canada                        5
# israel                        5
# u.s.a                         3
# united state of america       2
# unite states                  2
# australia                     2
# unitedstates                  2
# india                         2
# u.s                           2
# singapore                     2
# spain                         2
# brazil                        2
# united kingdom                2
# new zealand                   2
# poland                        2
# france                        2
# denmark                       2
# nigeria                       2
# uniyed states                 1
# america                       1
# puerto rico                   1
# united state                  1
# cuba                          1
# danmark                       1
# italy                         1
# international                 1
# united stated                 1
# remote (philippines)          1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
# ----> 2 df_salary_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_salary_usd['salary'] = df_salary_usd['salary'].str.replace(',', '')
df_salary_usd['salary'] = pd.to_numeric(df_salary_usd['salary'])

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                 min           mean      max
# state
# Michigan, Texas, Washington  340000  340000.000000   340000
# California, Oregon           200000  200000.000000   200000
# California, Colorado         176000  176000.000000   176000
# Georgia, Massachusetts       175000  175000.000000   175000
# Florida                       28800  157457.232143  2600000
# ...                             ...            ...      ...
# Louisiana                     35360   83269.090909   150000
# Massachusetts, Pennsylvania   83000   83000.000000    83000
# California, Maryland          81500   81500.000000    81500
# Arkansas                          4   74257.000000   144000
# Alabama, Montana              72000   72000.000000    72000
#
# [66 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_usd['timestamp'] = pd.to_datetime(df_salary_usd['timestamp'])

df_salary_recent = df_salary_usd[df_salary_usd['timestamp'].dt.year.isin([2021, 2022, 2023])]

df_salary_recent.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                   min           mean     max
# state
# Michigan, Texas, Washington    340000  340000.000000  340000
# California, Oregon             200000  200000.000000  200000
# California, Colorado           176000  176000.000000  176000
# Georgia, Massachusetts         175000  175000.000000  175000
# Alabama, District of Columbia  156000  156000.000000  156000
# ...                               ...            ...     ...
# Louisiana                       35360   83269.090909  150000
# Massachusetts, Pennsylvania     83000   83000.000000   83000
# Arkansas                        55000   81682.300000  144000
# California, Maryland            81500   81500.000000   81500
# Alabama, Montana                72000   72000.000000   72000
#
# [66 rows x 3 columns]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_salary_bonus = df_salary.copy()

# Keep only USD salaries
df_salary_bonus = df_salary_bonus[
    df_salary_bonus['currency'] == 'USD'
]

# Normalize country text
df_salary_bonus['country'] = (
    df_salary_bonus['country']
    .str.strip()
    .str.lower()
)

# Convert U.S. variations to one value
df_salary_bonus['country'] = df_salary_bonus['country'].replace(
    ['us', 'usa', 'united states', 'united states of america'],
    'US'
)

# Keep only U.S.
df_salary_bonus = df_salary_bonus[
    df_salary_bonus['country'] == 'US'
]

# Clean salary and convert it to numeric
df_salary_bonus['salary'] = (
    df_salary_bonus['salary']
    .str.replace(',', '', regex=False)
)

df_salary_bonus['salary'] = pd.to_numeric(
    df_salary_bonus['salary'],
    errors='coerce'
)

# Drop rows where salary could not be converted
df_salary_bonus = df_salary_bonus.dropna(subset=['salary'])

# Minimum, mean, and maximum salary by state
df_salary_bonus.groupby('state')['salary'].agg(
    ['min', 'mean', 'max']
).sort_values('mean', ascending=False)
# Out:
#                                                        min           mean  \
# state
# Michigan, Texas, Washington                         340000  340000.000000
# Indiana, Ohio                                       245000  245000.000000
# Alaska                                               27040  238025.887097
# Colorado, Nevada                                    190000  190000.000000
# California, Montana                                 185000  185000.000000
# ...                                                    ...            ...
# District of Columbia, Washington                     35000   35000.000000
# Delaware, Pennsylvania                               35000   35000.000000
# Alabama, California                                  29120   29120.000000
# District of Columbia, Maryland, Pennsylvania, V...   27040   27040.000000
# Maryland, New York                                   14000   14000.000000
#
#                                                          max
# state
# ...

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
salary_by_state = df_salary_bonus.groupby('state')['salary'].agg(
    ['min', 'mean', 'max']
).sort_values('mean', ascending=False)

salary_by_state.style.format({
    'min': '${:,.2f}',
    'mean': '${:,.2f}',
    'max': '${:,.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_8dc11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc11_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_8dc11_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8dc11_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dc11_level0_row0" class="row_heading level0 row0" >Michigan, Texas, Washington</th>
#       <td id="T_8dc11_row0_col0" class="data row0 col0" >$340,000.00</td>
#       <td id="T_8dc11_row0_col1" class="data row0 col1" >$340,000.00</td>
#       <td id="T_8dc11_row0_col2" class="data row0 col2" >$340,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
valid_states = [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
    'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
    'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
    'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
    'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri',
    'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey',
    'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
    'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
    'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
    'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'
]

df_salary_bonus = df_salary_bonus[
    df_salary_bonus['state'].isin(valid_states)
]

df_salary_bonus.groupby('state')['salary'].agg(
    ['min', 'mean', 'max']
).sort_values('mean', ascending=False)
# Out:
#                   min           mean       max
# state
# Alaska          27040  238025.887097  10000000
# California          0  114590.160400    875000
# Washington         72  107230.274390   1260000
# New York           80  105158.257252   3000000
# New Jersey      14850  101466.065104   5000044
# Massachusetts     155   98737.949759   1650000
# Virginia           57   94971.660526   1300000
# Connecticut         0   94039.280172   1900000
# Illinois            0   90543.708298   1100000
# Colorado           65   90184.292763    630000
# Maryland            0   89885.892393    353200
# Oregon              0   89657.068220    320000
# Texas               0   88747.016543   1200000
# Delaware        35000   88359.833333    220000
# Utah            18720   87525.297436    576000
# Georgia             0   86585.849421    860000
# Florida           150   83844.512770   2600000
# Pennsylvania       55   83307.380849   1100000
# Minnesota          40   81920.407246    321250
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
salary_stats = (
    df_salary_bonus
    .groupby('state')['salary']
    .describe(percentiles=[0.05, 0.25, 0.50, 0.75, 0.95])
)

salary_stats = salary_stats[
    ['count', 'min', '5%', '25%', '50%', '75%', '95%', 'max']
]

# Sort by median (50th percentile)
salary_stats = salary_stats.sort_values(
    '50%',
    ascending=False
)

salary_stats
# Out:
#                  count      min        5%       25%       50%        75%  \
# state
# California      2500.0      0.0  42000.00  71712.50  100330.0  148000.00
# Washington      1148.0     72.0  40000.00  65000.00   90325.5  135000.00
# New York        2103.0     80.0  41000.00  64000.00   89470.0  128000.00
# Massachusetts   1453.0    155.0  42000.00  64000.00   86000.0  120000.00
# Delaware          42.0  35000.0  41620.80  57073.25   84750.0  108750.00
# Maryland         539.0      0.0  39900.00  60000.00   83000.0  110301.50
# Connecticut      232.0      0.0  33617.50  61750.00   82000.0  100000.00
# Virginia         760.0     57.0  36955.00  58412.50   81000.0  115000.00
# Oregon           601.0      0.0  36400.00  60000.00   79000.0  110000.00
# Colorado         608.0     65.0  38837.00  58209.00   76998.5  111250.00
# Illinois        1169.0      0.0  37500.00  56000.00   76000.0  110000.00
# Texas           1209.0      0.0  35360.00  55000.00   76000.0  110000.00
# ...
