# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
len(df_food)
# Out:
# 125

# %%
# Try to print or display it nicely.
print("Rows:", df_food.shape[0])
print("Columns:", df_food.shape[1])
# Out:
# Rows: 125
# Columns: 61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
pd.DataFrame(df_food.dtypes)
# Out:
#                         0
# GPA                   str
# Gender              int64
# breakfast           int64
# calories_chicken    int64
# calories_day      float64
# ...                   ...
# type_sports           str
# veggies_day         int64
# vitamins            int64
# waffle_calories     int64
# weight                str
#
# [61 rows x 1 columns]

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.
column_info = pd.DataFrame({
    "Column": df_food.columns,
    "Data Type": df_food.dtypes
})

column_info
# Out:
#                                                     Column Data Type
# GPA                                                    GPA       str
# Gender                                              Gender     int64
# breakfast                                        breakfast     int64
# calories_chicken                          calories_chicken     int64
# calories_day                                  calories_day   float64
# calories_scone                              calories_scone   float64
# coffee                                              coffee     int64
# comfort_food                                  comfort_food       str
# comfort_food_reasons                  comfort_food_reasons       str
# comfort_food_reasons_coded      comfort_food_reasons_coded   float64
# cook                                                  cook   float64
# comfort_food_reasons_coded.1  comfort_food_reasons_coded.1     int64
# cuisine                                            cuisine   float64
# diet_current                                  diet_current       str
# diet_current_coded                      diet_current_coded     int64
# drink                                                drink   float64
# eating_changes                              eating_changes       str
# eating_changes_coded                  eating_changes_coded     int64
# eating_changes_coded1                eating_changes_coded1     int64
# eating_out                                      eating_out     int64
# employment                                      employment   float64
# ethnic_food                                    ethnic_food     int64
# exercise                                          exercise   float64
# father_education                          father_education   float64
# father_profession                        father_profession       str
# fav_cuisine                                    fav_cuisine       str
# fav_cuisine_coded                        fav_cuisine_coded     int64
# fav_food                                          fav_food   float64
# food_childhood                              food_childhood       str
# fries                                                fries     int64
# fruit_day                                        fruit_day     int64
# grade_level                                    grade_level     int64
# greek_food                                      greek_food     int64
# healthy_feeling                            healthy_feeling     int64
# healthy_meal                                  healthy_meal       str
# ideal_diet                                      ideal_diet       str
# ideal_diet_coded                          ideal_diet_coded     int64
# income                                              income   float64
# indian_food                                    indian_food     int64
# italian_food                                  italian_food     int64
# life_rewarding                              life_rewarding   float64
# marital_status                              marital_status   float64
# meals_dinner_friend                    meals_dinner_friend       str
# mother_education                          mother_education   float64
# mother_profession                        mother_profession       str
# nutritional_check                        nutritional_check     int64
# on_off_campus                                on_off_campus   float64
# parents_cook                                  parents_cook     int64
# pay_meal_out                                  pay_meal_out     int64
# persian_food                                  persian_food   float64
# self_perception_weight              self_perception_weight   float64
# soup                                                  soup   float64
# sports                                              sports   float64
# thai_food                                        thai_food     int64
# tortilla_calories                        tortilla_calories   float64
# turkey_calories                            turkey_calories     int64
# type_sports                                    type_sports       str
# veggies_day                                    veggies_day     int64
# vitamins                                          vitamins     int64
# waffle_calories                            waffle_calories     int64
# weight                                              weight       str

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.

df_food = df_food.dropna()
df_food
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# 20          3.3       2          1               610           3.0
# 22          3.7       2          1               610           3.0
# 23          3.7       2          2               610           3.0
# 25          2.8       1          2               720           3.0
# 26          3.7       2          1               610           2.0
# 27            3       2          1               610           4.0
# 31            4       2          1               610           3.0
# 34         3.65       1          1               610           3.0
# 35            3       1          1               610           2.0
# 37          3.4       1          1               720           4.0
# 38         3.89       1          1               610           3.0
# 40          3.4       2          1               430           3.0
# 44          3.2       1          1               610           4.0
# 46          3.8       2          1               430           2.0
# 51          3.3       2          1               610           4.0
# 54          3.5       2          1               610           3.0
# 56          3.8       2          1               720           4.0
# 57          2.8       1          1               610           4.0
# 58          3.5       1          1               610           3.0
# 60          3.6       1          1               610           4.0
# 62          3.9       2          1               610           4.0
# 64          3.5       1          1               610           3.0
# 67          3.6       1          1               610           2.0
# 68          3.2       1          1               430           3.0
# 70         3.73       1          1               610           3.0
# 73   3.79 bitch       2          1               720           4.0
# 75            3       1          1               610           3.0
# 76          3.7       1          2               610           3.0
# 77          3.1       2          2               265           2.0
# 78            3       1          1               720           3.0
# 79          3.9       2          1               720           3.0
# 81          3.5       1          2               610           3.0
# 84         3.83       1          1               720           3.0
# 85          2.6       1          1               265           3.0
# 86            3       1          1               610           3.0
# 87          3.2       2          1               720           3.0
# 91          3.8       1          2               610           2.0
# 96         3.92       2          1               430           3.0
# 103         3.7       1          1               610           3.0
#
#      calories_scone  coffee  \
# 1             420.0       2
# 2             420.0       2
# 4             420.0       2
# 6             420.0       2
# 7             420.0       1
# 9             315.0       2
# 10            980.0       2
# 11            420.0       2
# 12            420.0       2
# 13            420.0       2
# 14            420.0       2
# 17            980.0       2
# 18            980.0       1
# 20            980.0       2
# 22            420.0       1
# 23            420.0       2
# 25            420.0       2
# 26            420.0       1
# 27            980.0       2
# 31            420.0       2
# 34            420.0       2
# 35            420.0       2
# 37            420.0       2
# 38            980.0       2
# 40            315.0       1
# 44            420.0       2
# 46            420.0       1
# 51            980.0       1
# 54            420.0       2
# 56            315.0       2
# 57            980.0       2
# 58            420.0       2
# 60            420.0       2
# 62            980.0       2
# 64            420.0       1
# 67            420.0       1
# 68            315.0       1
# 70            980.0       2
# 73            420.0       2
# 75            420.0       2
# 76            420.0       1
# 77            420.0       1
# 78            420.0       2
# 79            420.0       2
# 81            420.0       1
# 84            420.0       2
# 85            315.0       2
# 86            420.0       2
# 87            420.0       1
# 91            420.0       2
# 96            420.0       2
# 103           420.0       2
#
#                                           comfort_food  \
# 1                          chocolate, chips, ice cream
# 2                      frozen yogurt, pizza, fast food
# 4                         Ice cream, chocolate, chips
# 6         Chocolate, ice cream, french fries, pretzels
# 7                     Ice cream, cheeseburgers, chips.
# 9                Mac and cheese, chocolate, and pasta
# 10   Pasta, grandma homemade chocolate cake anythin...
# 11              chocolate, pasta, soup, chips, popcorn
# 12                         Cookies, popcorn, and chips
# 13                          ice cream, cake, chocolate
# 14     Pizza, fruit, spaghetti, chicken and Potatoes
# 17                           chips, cookies, ice cream
# 18                                Chocolate, ice crea
# 20                              Fast food, pizza, subs
# 22                             burgers, chips, cookies
# 23                               Chilli, soup, pot pie
# 25             chocolate, ice cream/milkshake, cookies
# 26              Chips, ice cream, microwaveable foods
# 27                             Chicken fingers, pizza
# 31                              chips and dip, pepsi,
# 34                      french fries, chips, ice cream
# 35   mac n cheese, peanut butter and banana sandwic...
# 37                             chocolate, chips, candy
# 38                       chocolate, popcorn, ice cream
# 40          Pizza, Ice cream, fries, cereal, cookies
# 44         Potato chips, ice cream, chocolate, cookies
# 46                     popcorn, chips, candy, & fries
# 51                                              Burger
# 54      peanut butter sandwich, pretzals, garlic bread
# 56                     Pizza, Ice Cream, Chicken Wings
# 57             Pizza chocolate chips bagels ice Capps
# 58                         Chocolate, ice cream, pasta
# 60                  peanut butter, dessets, pretzels.
# 62                       ice cream, cookies, ice cream
# 64         cookies, nutella, ice cream, coffee, fruit
# 67      Ice cream, cake, mozzarella sticks, pierogies
# 68         Chips, Mac and cheese, pizza, French fries
# 70   Broccoli, spaghetti squash, quinoa, and grille...
# 73                                    Chips, ice cream
# 75   mac and cheese, potato soup, ice cream, chips ...
# 76               chocolate, pizza, and mashed potatoes
# 77                                Pizza cookies steak
# 78                     chocolate, fruit, and ice cream
# 79                                Chips sweets popcorn
# 81                 cake, French fries, chicken nuggets
# 84                  Pasta dishes, Cheesecake, Pancakes
# 85                           Ice cream, pizza, cookies
# 86   Chinese food, moes, sponge candy, homemade las...
# 87                        pizza, pasta, mac and cheese
# 91     Macaroni and cheese, chicken noodle soup, pizza
# 96        Ice cream, cake, pop, pizza, and milkshakes.
# 103  dark chocolate, terra chips, reese's cups(dark...
#
#                                   comfort_food_reasons  \
# 1                                 Stress, bored, anger
# 2                                      stress, sadness
# 4                           Stress, boredom, cravings
# 6                                      stress, boredom
# 7    I eat comfort food when im stressed out from s...
# 9                           Stress, anger and sadness
# 10                                            Boredom
# 11                       sadness, stress, cold weather
# 12                 Sadness, boredom, late night snack
# 13                 stress,  boredom, special occasions
# 14                    Friends, environment and boredom
# 17   I usually only eat comfort food when I'm bored...
# 18                                     Sadness, stress
# 20                             happiness, satisfaction
# 22                                sadness, depression
# 23                                 Stress and boredom
# 25                                             boredom
# 26                                  Boredom, lazyniss
# 27                                            Boredom
# 31                       stres, boredom, and nighttime
# 34                              boredom, stressed, sad
# 35                                     Boredom usually
# 37                                              Stress
# 38                                     boredom, stress
# 40                   Usually if I'm sad or depressed.
# 44                            Stress, boredom, craving
# 46                          sadness, boredom, & anger
# 51                                                Lazy
# 54                           stress, anger and boredom
# 56   I usually only eat comfort foods when I am bor...
# 57                                         Just cause
# 58                            Stress, boredom, sadness
# 60                           Sadness, boredom, lonely.
# 62                                    boredom, sadness
# 64                          Bordem, happiness, sadness
# 67                                             Boredom
# 68                             Stress, sadness, bored
# 70                             Bad day, bored, sadness
# 73                                     Boredom, stress
# 75                          sadness, stressed, boredom
# 76                                  boredom and stress
# 77                             Boredom comfort hunger
# 78                                     stress, boredom
# 79                                             Boredom
# 81                                    boredom, sadness
# 84                        Sadness, Loneliness, Boredom
# 85                                       Mostly Stress
# 86                                   boredom, sadness
# 87                            when i am sad or craving
# 91                                  Boredom and stress
# 96                    Happiness, sadness, celebration.
# 103  Anxiousness, watching TV I desire "comfort food"
#
#      comfort_food_reasons_coded  ...  soup  sports  thai_food  \
# 1                           1.0  ...   1.0     1.0          2
# 2                           1.0  ...   1.0     2.0          5
# 4                           1.0  ...   1.0     1.0          4
# 6                           1.0  ...   1.0     1.0          5
# 7                           1.0  ...   1.0     2.0          1
# 9                           1.0  ...   1.0     1.0          4
# 10                          2.0  ...   1.0     1.0          2
# 11                          3.0  ...   1.0     1.0          5
# 12                          3.0  ...   2.0     1.0          3
# 13                          1.0  ...   1.0     1.0          5
# 14                          2.0  ...   1.0     1.0          4
# 17                          2.0  ...   1.0     1.0          3
# 18                          3.0  ...   2.0     2.0          1
# 20                          7.0  ...   1.0     1.0          1
# 22                          3.0  ...   1.0     1.0          4
# 23                          1.0  ...   1.0     1.0          4
# 25                          2.0  ...   1.0     1.0          3
# 26                          2.0  ...   2.0     1.0          2
# 27                          2.0  ...   1.0     1.0          3
# 31                          1.0  ...   2.0     2.0          4
# 34                          2.0  ...   1.0     1.0          3
# 35                          2.0  ...   1.0     1.0          2
# 37                          1.0  ...   1.0     1.0          5
# 38                          2.0  ...   1.0     1.0          2
# 40                          3.0  ...   1.0     1.0          3
# 44                          1.0  ...   1.0     1.0          5
# 46                          3.0  ...   1.0     1.0          3
# 51                          5.0  ...   1.0     1.0          5
# 54                          1.0  ...   1.0     1.0          4
# 56                          2.0  ...   1.0     1.0          5
# 57                          9.0  ...   2.0     1.0          2
# 58                          1.0  ...   1.0     1.0          5
# 60                          3.0  ...   1.0     1.0          1
# 62                          2.0  ...   1.0     1.0          2
# 64                          2.0  ...   2.0     1.0          3
# 67                          2.0  ...   1.0     1.0          2
# 68                          1.0  ...   1.0     1.0          4
# 70                          2.0  ...   1.0     1.0          5
# 73                          2.0  ...   1.0     1.0          2
# 75                          3.0  ...   1.0     2.0          4
# 76                          2.0  ...   2.0     1.0          1
# 77                          2.0  ...   2.0     1.0          2
# 78                          1.0  ...   1.0     1.0          3
# 79                          2.0  ...   1.0     1.0          5
# 81                          2.0  ...   2.0     1.0          4
# 84                          3.0  ...   1.0     1.0          5
# 85                          1.0  ...   1.0     2.0          3
# 86                          2.0  ...   1.0     1.0          4
# 87                          3.0  ...   1.0     1.0          1
# 91                          2.0  ...   1.0     2.0          1
# 96                          7.0  ...   1.0     2.0          3
# 103                         8.0  ...   1.0     2.0          3
#
#     tortilla_calories  turkey_calories  \
# 1               725.0              690
# 2              1165.0              500
# 4               940.0              500
# 6               940.0              690
# 7               725.0              500
# 9               580.0              345
# 10              940.0              345
# 11              940.0              500
# 12              940.0              500
# 13             1165.0              850
# 14              940.0              500
# 17              940.0              500
# 18             1165.0              690
# 20             1165.0              850
# 22              940.0              850
# 23              940.0              690
# 25             1165.0              690
# 26             1165.0              850
# 27             1165.0              500
# 31              940.0              690
# 34              940.0              345
# 35              940.0              690
# 37              940.0              500
# 38             1165.0              690
# 40              940.0              500
# 44              725.0              500
# 46              725.0              345
# 51             1165.0              500
# 54              940.0              690
# 56             1165.0              500
# 57              725.0              345
# 58             1165.0              690
# 60             1165.0              690
# 62             1165.0              850
# 64              940.0              500
# 67              940.0              690
# 68              725.0              500
# 70             1165.0              500
# 73             1165.0              850
# 75              940.0              500
# 76             1165.0              690
# 77              725.0              345
# 78              580.0              345
# 79             1165.0              850
# 81              725.0              500
# 84              725.0              690
# 85              580.0              500
# 86              580.0              500
# 87             1165.0              690
# 91              725.0              500
# 96              725.0              500
# 103             725.0              345
#
#                                            type_sports veggies_day  vitamins  \
# 1                                          Basketball            4         2
# 2                                                 none           5         1
# 4                                             Softball           4         2
# 6                                               soccer           4         1
# 7                                                 none           4         2
# 9                                         field hockey           5         1
# 10                                              soccer           5         2
# 11                                             Running           5         1
# 12                              Soccer and basketball            3         2
# 13                               intramural volleyball           5         2
# 14                                              Hockey           5         1
# 17                                              hockey           4         2
# 18                                            dancing            5         1
# 20                                              Soccer           3         2
# 22                                   tennis soccer gym           3         1
# 23                                     Gaelic Football           4         1
# 25                                          Ice hockey           3         2
# 26                                              Hockey           3         2
# 27                                           Lacrosse            5         1
# 31                                      none organized           5         1
# 34                                            softball           4         1
# 35                                            Lacrosse           5         2
# 37                                             Dancing           4         2
# 38                                            Lacrosse           3         2
# 40                                          wrestling            4         2
# 44                                          Volleyball           5         1
# 46                                             soccer            4         2
# 51                                              Hockey           4         1
# 54                                              hockey           5         1
# 56                                              Hockey           5         1
# 57                                            softball           4         1
# 58                                              Skiing           5         1
# 60                             Water polo and running            5         1
# 62                                          Ice Hockey           4         1
# 64                                          Volleyball           5         1
# 67            Recreational Basketball, Equestrian Team           5         2
# 68                                              soccer           5         2
# 70                                      Rec Volleyball           5         1
# 73                                            baseball           4         1
# 75                             I danced in high school           4         1
# 76                                   horse back riding           2         2
# 77                                         Basketball            2         2
# 78                                  competitive skiing           4         1
# 79                        Rowing, Running, and Cycling           4         2
# 81                             softball and basketball           2         2
# 84                               Collegiate Water Polo           5         1
# 85                                      None right now           4         1
# 86                                volleyball, lacrosse           4         1
# 87                                        field hockey           4         1
# 91                                                crew           1         2
# 96                                              Soccer           2         1
# 103  When I can, rarely though play pool, darts, an...           5         1
#
#      waffle_calories                    weight
# 1                900                       155
# 2                900  I'm not answering this.
# 4                760                       190
# 6               1315                       180
# 7               1315                       137
# 9                900                       125
# 10               900                       116
# 11               900                       110
# 12               575                       264
# 13              1315                       123
# 14               900                       185
# 17               900                       170
# 18              1315                       135
# 20              1315                       175
# 22              1315                       185
# 23              1315                       185
# 25               760                       125
# 26              1315                       160
# 27              1315                       175
# 31              1315                       205
# 34              1315                       150
# 35               760                       150
# 37              1315                       170
# 38              1315                       150
# 40               760                       140
# 44               760                       170
# 46               900                       168
# 51              1315                       185
# 54               900                       165
# 56              1315                       175
# 57              1315                       140
# 58              1315                       155
# 60              1315                       135
# 62              1315                       210
# 64               760                       140
# 67              1315                   144 lbs
# 68               760                       145
# 70              1315                       140
# 73              1315                       200
# 75               900                       120
# 76              1315                       150
# 77               900                       200
# 78              1315                       135
# 79              1315                       145
# 81               900                       190
# 84               760                       167
# 85               760                       140
# 86               900                       190
# 87              1315                       155
# 91               900                       135
# 96               900                       210
# 103              760                       130
#
# [52 rows x 61 columns]

# %%
# Is there a second way to remove columns?

del df_food["ColumnName"]

# %%
# 🚀 Extra credit: What about a third way to remove columns?

df_food.pop("ColumnName")

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

df_food.isna().sum()
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  0
# coffee                          0
# comfort_food                    0
# comfort_food_reasons            0
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    0
# diet_current_coded              0
# drink                           0
# eating_changes                  0
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     0
# fav_cuisine_coded               0
# fav_food                        0
# food_childhood                  0
# fries                           0
# fruit_day                       0
# grade_level                     0
# greek_food                      0
# healthy_feeling                 0
# healthy_meal                    0
# ideal_diet                      0
# ideal_diet_coded                0
# income                          0
# indian_food                     0
# italian_food                    0
# life_rewarding                  0
# marital_status                  0
# meals_dinner_friend             0
# mother_education                0
# mother_profession               0
# nutritional_check               0
# on_off_campus                   0
# parents_cook                    0
# pay_meal_out                    0
# persian_food                    0
# self_perception_weight          0
# soup                            0
# sports                          0
# thai_food                       0
# tortilla_calories               0
# turkey_calories                 0
# type_sports                     0
# veggies_day                     0
# vitamins                        0
# waffle_calories                 0
# weight                          0
# dtype: int64

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

df_food.isna().sum().sum()

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.
df_food = df_food.dropna()

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
df_food["weight"] = pd.to_numeric(
    df_food["weight"], errors="coerce"
)

df_food.dropna(subset=["weight"], inplace=True)

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food.to_csv("data/food_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Savey save!
#       2
# ----> 3 df_food.to_csv("data/food_cleaned.csv", index=False)
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3976, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3972             float_format=float_format,
#    3973             decimal=decimal,
#    3974         )
#    3975
# -> 3976         return DataFrameRenderer(formatter).to_csv(
#    3977             path_or_buf,
#    3978             lineterminator=lineterminator,
#    3979             sep=sep,
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/io/formats/format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/io/common.py:797, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     795 # Only for write methods
#     796 if "r" not in mode and is_path:
# --> 797     check_parent_directory(str(handle))
#     799 if compression:
#     800     if compression != "zstd":
#     801         # compression libraries do not like an explicit text-mode
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/io/common.py:656, in check_parent_directory(path)
#     654 parent = Path(path).parent
#     655 if not parent.is_dir():
# --> 656     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.

df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 1  3.654       1          1               610           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 1       2                   chocolate, chips, ice cream
# 4       2                  Ice cream, chocolate, chips
# 6       2  Chocolate, ice cream, french fries, pretzels
# 7       1              Ice cream, cheeseburgers, chips.
# 9       2         Mac and cheese, chocolate, and pasta
#
#                                 comfort_food_reasons  \
# 1                               Stress, bored, anger
# 4                         Stress, boredom, cravings
# 6                                    stress, boredom
# 7  I eat comfort food when im stressed out from s...
# 9                         Stress, anger and sadness
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 1                         1.0  ...   1.0     1.0          2             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
# 6                         1.0  ...   1.0     1.0          5             940.0
# 7                         1.0  ...   1.0     2.0          1             725.0
# 9                         1.0  ...   1.0     1.0          4             580.0
#
#    turkey_calories   type_sports veggies_day  vitamins  waffle_calories  \
# 1              690   Basketball            4         2              900
# 4              500      Softball           4         2              760
# 6              690        soccer           4         1             1315
# 7              500          none           4         2             1315
# 9              345  field hockey           5         1              900
#
#    weight
# 1   155.0
# 4   190.0
# 6   180.0
# 7   137.0
# 9   125.0
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.

salary_data_set_path = '../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'
df_salary = pd.read_csv(salary_data_set_path, sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

len(df_salary)
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# If your job title needs additional context, please clarify here:                                                                                                                                                                            str
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)        str
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          float64
# Please indicate the currency                                                                                                                                                                                                                str
# If "Other," please indicate the currency here:                                                                                                                                                                                              str
# If your income needs additional context, please provide it here:                                                                                                                                                                            str
# What country do you work in?                                                                                                                                                                                                                str
# If you're in the U.S., what state do you work in?                                                                                                                                                                                           str
# What city do you work in?                                                                                                                                                                                                                   str
# How many years of professional work experience do you have overall?                                                                                                                                                                         str
# How many years of professional work experience do you have in your field?                                                                                                                                                                   str
# What is your highest level of education completed?                                                                                                                                                                                          str
# What is your gender?                                                                                                                                                                                                                        str
# What is your race? (Choose all that apply.)                                                                                                                                                                                                 str
# dtype: object

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education_completed', 'gender', 'race']

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_salary.industry.value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.
df_salary_tech = df_salary[df_salary.industry == 'Computing or Tech'].copy()
df_salary_tech.head()
# Out:
#              timestamp    age           industry  \
# 1   4/27/2021 11:02:22  25-34  Computing or Tech
# 8   4/27/2021 11:03:01  45-54  Computing or Tech
# 43  4/27/2021 11:04:04  25-34  Computing or Tech
# 44  4/27/2021 11:04:04  25-34  Computing or Tech
# 46  4/27/2021 11:04:07  35-44  Computing or Tech
#
#                                        title                 title_context  \
# 1   Change & Internal Communications Manager                           NaN
# 8                            Systems Analyst  Data developer/ETL Developer
# 43               Principal Software Engineer                           NaN
# 44                      Intelligence Analyst                           NaN
# 46                          Mobile developer                           NaN
#
#      salary  additional_compensation currency other_currency  \
# 1    54,600                   4000.0      GBP            NaN
# 8   112,000                  10000.0      USD            NaN
# 43  187,500                   5000.0      USD            NaN
# 44  110,000                  20000.0      USD            NaN
# 46  144,600                   2500.0      USD            NaN
#
#                    salary_context         country          state  \
# 1                             NaN  United Kingdom            NaN
# 8                             NaN              US       Missouri
# 43                            NaN   United States   Pennsylvania
# 44  Around 20,000 a year in stock             USA       Virginia
# 46                            NaN             USA  Massachusetts
#
#              city      total_yoe      field_yoe highest_education_completed  \
# 1       Cambridge   8 - 10 years      5-7 years              College degree
# 8       St. Louis  21 - 30 years  21 - 30 years              College degree
# 43     Pittsburgh   8 - 10 years      5-7 years              College degree
# 44  Arlington, VA   8 - 10 years   8 - 10 years             Master's degree
# 46         Boston      5-7 years      5-7 years                         PhD
#
#         gender   race
# 1   Non-binary  White
# 8        Woman  White
# 43       Woman  White
# 44         Man  White
# 46       Woman  White

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.
len(df_salary_tech)
# Out:
# 4699

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!

df_salary_tech.drop(
    df_salary_tech[df_salary_tech.currency != "USD"].index,
    inplace=True
)

df_salary_tech.currency.value_counts()
# Out:
# currency
# USD    3777
# Name: count, dtype: int64

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_tech.country.value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.
df_salary_tech.country = df_salary_tech.country.map(lambda country: country.strip())
df_salary_tech["country"] = df_salary_tech["country"].replace(
    [
        "United States",
        "USA",
        "US",
        "U.S.",
        "United States of America",
        "united states",
        "United states",
        "Usa",
        "usa",
        "us",
        "Us",
        "U.S.A.",
        "Unite States",
        "UnitedStates",
        "U.S",
        "United State of America",
        "U.S.A",
        "United States Of America",
        "united States",
        "United States of america",
        "U.s.",
        "United State"
    ],
    "US"
)

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary_tech.country.value_counts()
# Out:
# country
# US                      3716
# Canada                     5
# Israel                     5
# Australia                  2
# India                      2
# Spain                      2
# Brazil                     2
# United Kingdom             2
# New Zealand                2
# Poland                     2
# France                     2
# Nigeria                    2
# Uniyed states              1
# America                    1
# Puerto Rico                1
# Cuba                       1
# Danmark                    1
# Italy                      1
# International              1
# United Stated              1
# Remote (philippines)       1
# Singapore                  1
# Uruguay                    1
# Mexico                     1
# United Stateds             1
# ISA                        1
# singapore                  1
# Pakistan                   1
# Netherlands                1
# China                      1
# San Francisco              1
# Romania                    1
# United STates              1
# Japan                      1
# United Stares              1
# Australian                 1
# Denmark                    1
# Jamaica                    1
# Unites States              1
# Thailand                   1
# Colombia                   1
# denmark                    1
# Ghana                      1
# ss                         1
# Burma                      1
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary.groupby("STATE_COLUMN")["SALARY_COLUMN"].agg(["min", "mean", "max"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 3
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
#       2
# ----> 3 df_salary.groupby("STATE_COLUMN")["SALARY_COLUMN"].agg(["min", "mean", "max"])
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
#   10833             raise TypeError("You have to supply one of 'by' and 'level'")
#   10834
# > 10835         return DataFrameGroupBy(
#   10836             obj=self,
#   10837             keys=by,
#   10838             level=level,
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'STATE_COLUMN'

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary["SalaryUSD"] = pd.to_numeric(
    df_salary["SalaryUSD"], errors="coerce"
)

df_salary.dropna(subset=["SalaryUSD"], inplace=True)

df_salary.groupby("State")["SalaryUSD"].agg(["min", "mean", "max"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'SalaryUSD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 # Fix it in-place.
#       2 df_salary["SalaryUSD"] = pd.to_numeric(
# ----> 3     df_salary["SalaryUSD"], errors="coerce"
#       4 )
#       5
#       6 df_salary.dropna(subset=["SalaryUSD"], inplace=True)
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/ds-fall-2026/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'SalaryUSD'

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary["salary"] = pd.to_numeric(
    df_salary["salary"], errors="coerce"
)
df_salary.dropna(subset=["salary"], inplace=True)
df_salary["timestamp"] = pd.to_datetime(df_salary["timestamp"])

df_salary_filtered = df_salary[
    df_salary["timestamp"].dt.year.isin([2021, 2022, 2023])
]

df_salary_filtered.groupby("state")["salary"].agg(["min", "mean", "max"])
# Out:
#                                                          min           mean  \
# state
# Alabama                                                  0.0   68424.250000
# Alabama, California                                  29120.0   29120.000000
# Alabama, Oregon                                      50000.0   50000.000000
# Alaska                                               47840.0   82652.533333
# Arizona                                              26500.0   86190.060241
# Arizona, California                                  90000.0   90000.000000
# Arizona, New York                                    72000.0   72000.000000
# Arkansas                                             28080.0   67005.440000
# California                                               0.0  113612.700405
# California, Colorado                                176000.0  176000.000000
# California, District of Columbia, Illinois, Iow...  130000.0  130000.000000
# California, Illinois, Massachusetts, North Caro...   85000.0   85000.000000
# California, Maryland                                 81500.0   81500.000000
# California, New York                                 48000.0   48000.000000
# California, Oregon                                  200000.0  200000.000000
# Colorado                                                65.0   87244.088608
# Connecticut                                              0.0   89062.647059
# Delaware                                             35000.0  103455.555556
# Delaware, Pennsylvania                               35000.0   35000.000000
# District of Columbia                                    40.0  110124.701835
# District of Columbia, Virginia                       80900.0  101700.000000
# District of Columbia, Washington                     35000.0   35000.000000
# Florida                                                150.0   79460.919786
# Florida, New Hampshire, Wisconsin                    70000.0   70000.000000
# Georgia                                                  0.0   85621.421965
# Hawaii                                               32460.0   65270.000000
# Idaho                                                   38.0   72550.500000
# Illinois                                                 0.0   88123.874608
# Illinois, North Carolina                             52000.0   52000.000000
# Indiana                                                105.0   80178.446809
# Indiana, Massachusetts                              132000.0  132000.000000
# Iowa                                                 13000.0   68420.595238
# Iowa, Nebraska                                       48000.0   48000.000000
# Kansas                                                  52.0   68686.189189
# Kansas, Missouri                                     64000.0   64000.000000
# Kentucky                                                 0.0   66174.876923
# Louisiana                                            20000.0   75958.368421
# Louisiana, Washington                               117000.0  117000.000000
# Maine                                                26000.0   65832.914894
# Maryland                                                 0.0   89366.050000
# Maryland, New York                                   14000.0   14000.000000
# Maryland, Virginia                                   78000.0   78000.000000
# Massachusetts                                          155.0   99872.434343
# Massachusetts, New Hampshire                         60000.0   60000.000000
# Michigan                                                55.0   77597.371069
# Michigan, Texas, Washington                         340000.0  340000.000000
# Minnesota                                               40.0   83155.450262
# Mississippi                                          30000.0   59661.538462
# Mississippi, Missouri                               110000.0  110000.000000
# Missouri                                                70.0   67334.321739
# Montana                                              19200.0   71369.272727
# Nebraska                                             18000.0   79161.062500
# Nevada                                                  55.0   82215.480000
# New Hampshire                                           55.0   68619.194444
# New Jersey                                           14850.0  129931.842975
# New Jersey, New York                                135000.0  138666.666667
# New Jersey, Pennsylvania                             40200.0   91600.000000
# New Mexico                                              78.0   74496.760000
# New York                                                80.0  106875.209459
# New York, Oregon, Vermont                            53000.0   53000.000000
# New York, Virginia                                   65000.0   65000.000000
# North Carolina                                       15000.0   77154.964706
# North Dakota                                             0.0   62217.333333
# Ohio                                                    36.0   78993.337778
# Oklahoma                                             25000.0   62752.586207
# Oregon                                                   0.0   90191.924419
# Oregon, Washington                                   52900.0   52900.000000
# Pennsylvania                                             0.0   80780.869403
# Pennsylvania, Rhode Island                           62000.0   62000.000000
# Rhode Island                                         27040.0   73162.631579
# South Carolina                                           0.0   63141.648649
# South Dakota                                         33000.0   46625.000000
# Tennessee                                            24000.0   77698.921053
# Texas                                                    0.0   88761.618280
# Utah                                                 28000.0   91444.551020
# Vermont                                              32000.0   64075.578947
# Virginia                                                57.0   96219.045455
# Washington                                              72.0   98022.110727
# West Virginia                                            0.0   52754.375000
# Wisconsin                                                1.0   83000.628788
# Wyoming                                              42500.0   59906.333333
#
#                                                           max
# state
# Alabama                                              350000.0
# Alabama, California                                   29120.0
# Alabama, Oregon                                       50000.0
# Alaska                                               200000.0
# Arizona                                              380000.0
# Arizona, California                                   90000.0
# Arizona, New York                                     72000.0
# Arkansas                                             145000.0
# California                                           520000.0
# California, Colorado                                 176000.0
# California, District of Columbia, Illinois, Iow...   130000.0
# California, Illinois, Massachusetts, North Caro...    85000.0
# California, Maryland                                  81500.0
# California, New York                                  48000.0
# California, Oregon                                   200000.0
# Colorado                                             200000.0
# Connecticut                                          270000.0
# Delaware                                             220000.0
# Delaware, Pennsylvania                                35000.0
# District of Columbia                                1250000.0
# District of Columbia, Virginia                       115000.0
# District of Columbia, Washington                      35000.0
# Florida                                              645000.0
# Florida, New Hampshire, Wisconsin                     70000.0
# Georgia                                              860000.0
# Hawaii                                               142000.0
# Idaho                                                300000.0
# Illinois                                             340000.0
# Illinois, North Carolina                              52000.0
# Indiana                                              925000.0
# Indiana, Massachusetts                               132000.0
# Iowa                                                 142000.0
# Iowa, Nebraska                                        48000.0
# Kansas                                               167000.0
# Kansas, Missouri                                      64000.0
# Kentucky                                             175000.0
# Louisiana                                            200000.0
# Louisiana, Washington                                117000.0
# Maine                                                173000.0
# Maryland                                             353200.0
# Maryland, New York                                    14000.0
# Maryland, Virginia                                    78000.0
# Massachusetts                                        400000.0
# Massachusetts, New Hampshire                          60000.0
# Michigan                                             240000.0
# Michigan, Texas, Washington                          340000.0
# Minnesota                                            215000.0
# Mississippi                                          125000.0
# Mississippi, Missouri                                110000.0
# Missouri                                             200000.0
# Montana                                              145000.0
# Nebraska                                             224000.0
# Nevada                                               165000.0
# New Hampshire                                        208000.0
# New Jersey                                          5000044.0
# New Jersey, New York                                 141000.0
# New Jersey, Pennsylvania                             143000.0
# New Mexico                                           177000.0
# New York                                             590000.0
# New York, Oregon, Vermont                             53000.0
# New York, Virginia                                    65000.0
# North Carolina                                       165000.0
# North Dakota                                          96000.0
# Ohio                                                 954000.0
# Oklahoma                                             180000.0
# Oregon                                               230000.0
# Oregon, Washington                                    52900.0
# Pennsylvania                                         252000.0
# Pennsylvania, Rhode Island                            62000.0
# Rhode Island                                         150000.0
# South Carolina                                       223000.0
# South Dakota                                          60000.0
# Tennessee                                            275000.0
# Texas                                                300000.0
# Utah                                                 576000.0
# Vermont                                              120000.0
# Virginia                                            1300000.0
# Washington                                           300000.0
# West Virginia                                        120000.0
# Wisconsin                                            920000.0
# Wyoming                                               98000.0

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary["timestamp"] = pd.to_datetime(df_salary["timestamp"])

df_salary_filtered = df_salary[
    df_salary["timestamp"].dt.year.isin([2021, 2022, 2023])
]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
