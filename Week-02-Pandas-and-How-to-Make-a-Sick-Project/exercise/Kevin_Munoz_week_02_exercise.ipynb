# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy

# %%
# Import here.
import numpy as np
import pandas as pd

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
print(len(df_food))
# Out:
# 125

# %%
# Try to print or display it nicely.
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.dtypes
# Out:
# GPA                                 str
# Gender                            int64
# breakfast                         int64
# calories_chicken                  int64
# calories_day                    float64
# calories_scone                  float64
# coffee                            int64
# comfort_food                        str
# comfort_food_reasons                str
# comfort_food_reasons_coded      float64
# cook                            float64
# comfort_food_reasons_coded.1      int64
# cuisine                         float64
# diet_current                        str
# diet_current_coded                int64
# drink                           float64
# eating_changes                      str
# eating_changes_coded              int64
# eating_changes_coded1             int64
# eating_out                        int64
# employment                      float64
# ethnic_food                       int64
# exercise                        float64
# father_education                float64
# father_profession                   str
# fav_cuisine                         str
# fav_cuisine_coded                 int64
# fav_food                        float64
# food_childhood                      str
# fries                             int64
# fruit_day                         int64
# grade_level                       int64
# greek_food                        int64
# healthy_feeling                   int64
# healthy_meal                        str
# ideal_diet                          str
# ideal_diet_coded                  int64
# income                          float64
# indian_food                       int64
# italian_food                      int64
# life_rewarding                  float64
# marital_status                  float64
# meals_dinner_friend                 str
# mother_education                float64
# mother_profession                   str
# nutritional_check                 int64
# on_off_campus                   float64
# parents_cook                      int64
# pay_meal_out                      int64
# persian_food                    float64
# self_perception_weight          float64
# soup                            float64
# sports                          float64
# thai_food                         int64
# tortilla_calories               float64
# turkey_calories                   int64
# type_sports                         str
# veggies_day                       int64
# vitamins                          int64
# waffle_calories                   int64
# weight                              str
# dtype: object

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.

df_food.dtypes.reset_index().rename(columns={"index": "Column", 0: "Type"})
# Out:
#                           Column     Type
# 0                            GPA      str
# 1                         Gender    int64
# 2                      breakfast    int64
# 3               calories_chicken    int64
# 4                   calories_day  float64
# 5                 calories_scone  float64
# 6                         coffee    int64
# 7                   comfort_food      str
# 8           comfort_food_reasons      str
# 9     comfort_food_reasons_coded  float64
# 10                          cook  float64
# 11  comfort_food_reasons_coded.1    int64
# 12                       cuisine  float64
# 13                  diet_current      str
# 14            diet_current_coded    int64
# 15                         drink  float64
# 16                eating_changes      str
# 17          eating_changes_coded    int64
# 18         eating_changes_coded1    int64
# 19                    eating_out    int64
# 20                    employment  float64
# 21                   ethnic_food    int64
# 22                      exercise  float64
# 23              father_education  float64
# 24             father_profession      str
# 25                   fav_cuisine      str
# 26             fav_cuisine_coded    int64
# 27                      fav_food  float64
# 28                food_childhood      str
# 29                         fries    int64
# 30                     fruit_day    int64
# 31                   grade_level    int64
# 32                    greek_food    int64
# 33               healthy_feeling    int64
# 34                  healthy_meal      str
# 35                    ideal_diet      str
# 36              ideal_diet_coded    int64
# 37                        income  float64
# 38                   indian_food    int64
# 39                  italian_food    int64
# 40                life_rewarding  float64
# 41                marital_status  float64
# 42           meals_dinner_friend      str
# 43              mother_education  float64
# 44             mother_profession      str
# 45             nutritional_check    int64
# 46                 on_off_campus  float64
# 47                  parents_cook    int64
# 48                  pay_meal_out    int64
# 49                  persian_food  float64
# 50        self_perception_weight  float64
# 51                          soup  float64
# 52                        sports  float64
# 53                     thai_food    int64
# 54             tortilla_calories  float64
# 55               turkey_calories    int64
# 56                   type_sports      str
# 57                   veggies_day    int64
# 58                      vitamins    int64
# 59               waffle_calories    int64
# 60                        weight      str

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.
df_food_col_subset = df_food[['calories_day', 'weight', 'Gender']]
df_food_col_subset.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %%
# Is there a second way to remove columns?

df_food_col_subset_v2 = df_food.drop(columns=['calories_day', 'weight', 'Gender' ])
df_food_col_subset.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %%
# 🚀 Extra credit: What about a third way to remove columns?

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

df_food.isnull().sum().sum()
# Out:
# np.int64(149)

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.
df_food_col_subset.dropna(inplace=True)

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂

df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.
df_food_col_subset['weight'] = pd.to_numeric(df_food_col_subset['weight'], errors='coerce')
df_food_col_subset.dropna(subset=['weight'], inplace=True)
df_food_col_subset.head()
# Out:
#    calories_day  weight  Gender
# 1           3.0   155.0       1
# 4           2.0   190.0       1
# 5           3.0   190.0       1
# 6           3.0   180.0       2
# 7           3.0   137.0       1

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_col_subset.to_csv('../data/cleaned_food_subset.csv', index=False)

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.
manager_set_path = '/workspaces/ds-fall-2026/Week-02-Pandas-and-How-to-Make-a-Sick-Project/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'
df_salary = pd.read_csv(manager_set_path, sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
print(len(df_salary))
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# If your job title needs additional context, please clarify here:                                                                                                                                                                            str
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)        str
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          float64
# Please indicate the currency                                                                                                                                                                                                                str
# If "Other," please indicate the currency here:                                                                                                                                                                                              str
# If your income needs additional context, please provide it here:                                                                                                                                                                            str
# What country do you work in?                                                                                                                                                                                                                str
# If you're in the U.S., what state do you work in?                                                                                                                                                                                           str
# What city do you work in?                                                                                                                                                                                                                   str
# How many years of professional work experience do you have overall?                                                                                                                                                                         str
# How many years of professional work experience do you have in your field?                                                                                                                                                                   str
# What is your highest level of education completed?                                                                                                                                                                                          str
# What is your gender?                                                                                                                                                                                                                        str
# What is your race? (Choose all that apply.)                                                                                                                                                                                                 str
# dtype: object

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation','currency', 'currency_other', 'income_context', 'country', 'state', 'city', 'years_experience_overall', 'years_experience_field', 'education', 'gender', 'race']

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary.industry.value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.
df_salary_tech.shape
# Out:
# (4699, 18)

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!
df_salary_tech = df_salary_tech[df_salary_tech['currency'] == 'USD']

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_tech.country.value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.
df_salary_tech['country'] = df_salary_tech['country'].replace(['United States', 'USA', 'US', 'United States of America', 'america'], 'US')

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech.shape
# Out:
# (3777, 18)

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_tech.groupby('state')['salary'].agg(['min','mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                      min           mean        max
# state
# Michigan, Texas, Washington     340000.0  340000.000000   340000.0
# Florida                          28800.0  210711.000000  2600000.0
# California, Oregon              200000.0  200000.000000   200000.0
# California, Colorado            176000.0  176000.000000   176000.0
# Delaware                        169000.0  169000.000000   169000.0
# Connecticut                      68000.0  161610.000000   270000.0
# California                           0.0  153286.988827   520000.0
# New York                         14000.0  146594.112150   590000.0
# Wisconsin                            1.0  145806.888889   920000.0
# District of Columbia             59000.0  142923.076923   200000.0
# New Jersey, New York            135000.0  137500.000000   140000.0
# Ohio                             42000.0  137066.666667   954000.0
# Washington                          72.0  136923.916667   300000.0
# Massachusetts                    41000.0  125899.155844   400000.0
# Nevada                          107100.0  124550.000000   142000.0
# New Jersey                       67500.0  124090.909091   192000.0
# Oregon                           16200.0  122640.000000   230000.0
# West Virginia                   120000.0  120000.000000   120000.0
# Maryland                         62000.0  119955.461538   176000.0
# Illinois                         36000.0  117555.571429   228800.0
# Alabama                          35000.0  117400.000000   350000.0
# Louisiana, Washington           117000.0  117000.000000   117000.0
# Pennsylvania                     52000.0  116826.388889   237000.0
# Georgia                          29120.0  115297.647059   242000.0
# Virginia                         58750.0  115086.696970   378000.0
# Montana                          65000.0  112666.666667   145000.0
# Kansas                           41500.0  109666.666667   167000.0
# Colorado                         49400.0  109291.891892   165000.0
# District of Columbia, Virginia  109200.0  109200.000000   109200.0
# Vermont                          91250.0  105625.000000   120000.0
# Idaho                            74860.0  105465.000000   170000.0
# Utah                             33280.0  105023.333333   176000.0
# Maine                            50000.0  103833.333333   173000.0
# Texas                            10700.0  103685.245902   190000.0
# Kentucky                         62000.0  102500.000000   125000.0
# Iowa                             63000.0  101200.000000   142000.0
# Minnesota                        52124.0  101064.941176   210000.0
# Rhode Island                     76000.0   99475.000000   122950.0
# North Carolina                   29000.0   97841.666667   165000.0
# Arizona                          35000.0   97833.333333   145000.0
# Michigan                         41600.0   95758.823529   235000.0
# New Mexico                       82000.0   95733.333333   115200.0
# Tennessee                        61500.0   91750.000000   144000.0
# New Hampshire                       55.0   87175.833333   130000.0
# Oklahoma                         36958.0   84802.571429   180000.0
# Indiana                          15000.0   82875.000000   140000.0
# California, Maryland             81500.0   81500.000000    81500.0
# Louisiana                        75000.0   80500.000000    84000.0
# Missouri                            80.0   80339.923077   200000.0
# Nebraska                         43000.0   76736.000000   140000.0
# Arkansas                             4.0   58001.000000    95000.0
# South Carolina                   40000.0   40000.000000    40000.0
# Alabama, District of Columbia        NaN            NaN        NaN
# Alabama, Montana                     NaN            NaN        NaN
# Alaska                               NaN            NaN        NaN
# Arizona, Utah                        NaN            NaN        NaN
# Georgia, Massachusetts               NaN            NaN        NaN
# Georgia, Washington                  NaN            NaN        NaN
# Massachusetts, New Hampshire         NaN            NaN        NaN
# Massachusetts, Pennsylvania          NaN            NaN        NaN
# Massachusetts, Rhode Island          NaN            NaN        NaN
# Mississippi                          NaN            NaN        NaN
# New York, Texas                      NaN            NaN        NaN
# North Dakota                         NaN            NaN        NaN
# South Dakota                         NaN            NaN        NaN
# Utah, Vermont                        NaN            NaN        NaN

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_tech.groupby('state')['salary'].agg(['min','mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                      min           mean        max
# state
# Michigan, Texas, Washington     340000.0  340000.000000   340000.0
# Florida                          28800.0  210711.000000  2600000.0
# California, Oregon              200000.0  200000.000000   200000.0
# California, Colorado            176000.0  176000.000000   176000.0
# Delaware                        169000.0  169000.000000   169000.0
# Connecticut                      68000.0  161610.000000   270000.0
# California                           0.0  153286.988827   520000.0
# New York                         14000.0  146594.112150   590000.0
# Wisconsin                            1.0  145806.888889   920000.0
# District of Columbia             59000.0  142923.076923   200000.0
# New Jersey, New York            135000.0  137500.000000   140000.0
# Ohio                             42000.0  137066.666667   954000.0
# Washington                          72.0  136923.916667   300000.0
# Massachusetts                    41000.0  125899.155844   400000.0
# Nevada                          107100.0  124550.000000   142000.0
# New Jersey                       67500.0  124090.909091   192000.0
# Oregon                           16200.0  122640.000000   230000.0
# West Virginia                   120000.0  120000.000000   120000.0
# Maryland                         62000.0  119955.461538   176000.0
# Illinois                         36000.0  117555.571429   228800.0
# Alabama                          35000.0  117400.000000   350000.0
# Louisiana, Washington           117000.0  117000.000000   117000.0
# Pennsylvania                     52000.0  116826.388889   237000.0
# Georgia                          29120.0  115297.647059   242000.0
# Virginia                         58750.0  115086.696970   378000.0
# Montana                          65000.0  112666.666667   145000.0
# Kansas                           41500.0  109666.666667   167000.0
# Colorado                         49400.0  109291.891892   165000.0
# District of Columbia, Virginia  109200.0  109200.000000   109200.0
# Vermont                          91250.0  105625.000000   120000.0
# Idaho                            74860.0  105465.000000   170000.0
# Utah                             33280.0  105023.333333   176000.0
# Maine                            50000.0  103833.333333   173000.0
# Texas                            10700.0  103685.245902   190000.0
# Kentucky                         62000.0  102500.000000   125000.0
# Iowa                             63000.0  101200.000000   142000.0
# Minnesota                        52124.0  101064.941176   210000.0
# Rhode Island                     76000.0   99475.000000   122950.0
# North Carolina                   29000.0   97841.666667   165000.0
# Arizona                          35000.0   97833.333333   145000.0
# Michigan                         41600.0   95758.823529   235000.0
# New Mexico                       82000.0   95733.333333   115200.0
# Tennessee                        61500.0   91750.000000   144000.0
# New Hampshire                       55.0   87175.833333   130000.0
# Oklahoma                         36958.0   84802.571429   180000.0
# Indiana                          15000.0   82875.000000   140000.0
# California, Maryland             81500.0   81500.000000    81500.0
# Louisiana                        75000.0   80500.000000    84000.0
# Missouri                            80.0   80339.923077   200000.0
# Nebraska                         43000.0   76736.000000   140000.0
# Arkansas                             4.0   58001.000000    95000.0
# South Carolina                   40000.0   40000.000000    40000.0
# Alabama, District of Columbia        NaN            NaN        NaN
# Alabama, Montana                     NaN            NaN        NaN
# Alaska                               NaN            NaN        NaN
# Arizona, Utah                        NaN            NaN        NaN
# Georgia, Massachusetts               NaN            NaN        NaN
# Georgia, Washington                  NaN            NaN        NaN
# Massachusetts, New Hampshire         NaN            NaN        NaN
# Massachusetts, Pennsylvania          NaN            NaN        NaN
# Massachusetts, Rhode Island          NaN            NaN        NaN
# Mississippi                          NaN            NaN        NaN
# New York, Texas                      NaN            NaN        NaN
# North Dakota                         NaN            NaN        NaN
# South Dakota                         NaN            NaN        NaN
# Utah, Vermont                        NaN            NaN        NaN

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech['timestamp'] = pd.to_datetime(df_salary_tech['timestamp'], errors='coerce')

df_salary_tech_new = df_salary_tech[df_salary_tech['timestamp'].dt.year.isin([2021, 2022, 2023])]

df_salary_tech.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False).reset_index()
# Out:
#                              state       min           mean        max
# 0      Michigan, Texas, Washington  340000.0  340000.000000   340000.0
# 1                          Florida   28800.0  210711.000000  2600000.0
# 2               California, Oregon  200000.0  200000.000000   200000.0
# 3             California, Colorado  176000.0  176000.000000   176000.0
# 4                         Delaware  169000.0  169000.000000   169000.0
# 5                      Connecticut   68000.0  161610.000000   270000.0
# 6                       California       0.0  153286.988827   520000.0
# 7                         New York   14000.0  146594.112150   590000.0
# 8                        Wisconsin       1.0  145806.888889   920000.0
# 9             District of Columbia   59000.0  142923.076923   200000.0
# 10            New Jersey, New York  135000.0  137500.000000   140000.0
# 11                            Ohio   42000.0  137066.666667   954000.0
# 12                      Washington      72.0  136923.916667   300000.0
# 13                   Massachusetts   41000.0  125899.155844   400000.0
# 14                          Nevada  107100.0  124550.000000   142000.0
# 15                      New Jersey   67500.0  124090.909091   192000.0
# 16                          Oregon   16200.0  122640.000000   230000.0
# 17                   West Virginia  120000.0  120000.000000   120000.0
# 18                        Maryland   62000.0  119955.461538   176000.0
# 19                        Illinois   36000.0  117555.571429   228800.0
# 20                         Alabama   35000.0  117400.000000   350000.0
# 21           Louisiana, Washington  117000.0  117000.000000   117000.0
# 22                    Pennsylvania   52000.0  116826.388889   237000.0
# 23                         Georgia   29120.0  115297.647059   242000.0
# 24                        Virginia   58750.0  115086.696970   378000.0
# 25                         Montana   65000.0  112666.666667   145000.0
# 26                          Kansas   41500.0  109666.666667   167000.0
# 27                        Colorado   49400.0  109291.891892   165000.0
# 28  District of Columbia, Virginia  109200.0  109200.000000   109200.0
# 29                         Vermont   91250.0  105625.000000   120000.0
# 30                           Idaho   74860.0  105465.000000   170000.0
# 31                            Utah   33280.0  105023.333333   176000.0
# 32                           Maine   50000.0  103833.333333   173000.0
# 33                           Texas   10700.0  103685.245902   190000.0
# 34                        Kentucky   62000.0  102500.000000   125000.0
# 35                            Iowa   63000.0  101200.000000   142000.0
# 36                       Minnesota   52124.0  101064.941176   210000.0
# 37                    Rhode Island   76000.0   99475.000000   122950.0
# 38                  North Carolina   29000.0   97841.666667   165000.0
# 39                         Arizona   35000.0   97833.333333   145000.0
# 40                        Michigan   41600.0   95758.823529   235000.0
# 41                      New Mexico   82000.0   95733.333333   115200.0
# 42                       Tennessee   61500.0   91750.000000   144000.0
# 43                   New Hampshire      55.0   87175.833333   130000.0
# 44                        Oklahoma   36958.0   84802.571429   180000.0
# 45                         Indiana   15000.0   82875.000000   140000.0
# 46            California, Maryland   81500.0   81500.000000    81500.0
# 47                       Louisiana   75000.0   80500.000000    84000.0
# 48                        Missouri      80.0   80339.923077   200000.0
# 49                        Nebraska   43000.0   76736.000000   140000.0
# 50                        Arkansas       4.0   58001.000000    95000.0
# 51                  South Carolina   40000.0   40000.000000    40000.0
# 52   Alabama, District of Columbia       NaN            NaN        NaN
# 53                Alabama, Montana       NaN            NaN        NaN
# 54                          Alaska       NaN            NaN        NaN
# 55                   Arizona, Utah       NaN            NaN        NaN
# 56          Georgia, Massachusetts       NaN            NaN        NaN
# 57             Georgia, Washington       NaN            NaN        NaN
# 58    Massachusetts, New Hampshire       NaN            NaN        NaN
# 59     Massachusetts, Pennsylvania       NaN            NaN        NaN
# 60     Massachusetts, Rhode Island       NaN            NaN        NaN
# 61                     Mississippi       NaN            NaN        NaN
# 62                 New York, Texas       NaN            NaN        NaN
# 63                    North Dakota       NaN            NaN        NaN
# 64                    South Dakota       NaN            NaN        NaN
# 65                   Utah, Vermont       NaN            NaN        NaN

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
