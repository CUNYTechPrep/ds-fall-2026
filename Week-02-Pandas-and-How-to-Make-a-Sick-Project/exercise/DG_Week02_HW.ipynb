# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)

df_food.shape
# Out:
# (125, 61)

# %%
# Try to print or display it nicely.
print(f"Rows: {df_food.shape[0]}, Columns: {df_food.shape[1]}")
# Out:
# Rows: 125, Columns: 61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
print(df_food.dtypes)
# Out:
# GPA                     str
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports             str
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight                  str
# Length: 61, dtype: object

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.
pd.DataFrame(df_food.dtypes, columns=["type"])
# Out:
#                                  type
# GPA                               str
# Gender                          int64
# breakfast                       int64
# calories_chicken                int64
# calories_day                  float64
# calories_scone                float64
# coffee                          int64
# comfort_food                      str
# comfort_food_reasons              str
# comfort_food_reasons_coded    float64
# cook                          float64
# comfort_food_reasons_coded.1    int64
# cuisine                       float64
# diet_current                      str
# diet_current_coded              int64
# drink                         float64
# eating_changes                    str
# eating_changes_coded            int64
# eating_changes_coded1           int64
# eating_out                      int64
# employment                    float64
# ethnic_food                     int64
# exercise                      float64
# father_education              float64
# father_profession                 str
# fav_cuisine                       str
# fav_cuisine_coded               int64
# fav_food                      float64
# food_childhood                    str
# fries                           int64
# fruit_day                       int64
# grade_level                     int64
# greek_food                      int64
# healthy_feeling                 int64
# healthy_meal                      str
# ideal_diet                        str
# ideal_diet_coded                int64
# income                        float64
# indian_food                     int64
# italian_food                    int64
# life_rewarding                float64
# marital_status                float64
# meals_dinner_friend               str
# mother_education              float64
# mother_profession                 str
# nutritional_check               int64
# on_off_campus                 float64
# parents_cook                    int64
# pay_meal_out                    int64
# persian_food                  float64
# self_perception_weight        float64
# soup                          float64
# sports                        float64
# thai_food                       int64
# tortilla_calories             float64
# turkey_calories                 int64
# type_sports                       str
# veggies_day                     int64
# vitamins                        int64
# waffle_calories                 int64
# weight                            str

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.
df_food_col_subset = df_food[["calories_day","weight","Gender"]].copy()
df_food_col_subset
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %%
# Is there a second way to remove columns?

df_food_subset = df_food.filter(["calories_day","weight","Gender"]).copy()
df_food_subset
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %%
# 🚀 Extra credit: What about a third way to remove columns?
df_food_col_subset2 = df_food.loc[:, ["calories_day","weight","Gender"]].copy()
df_food_col_subset2
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food_col_subset.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.
df_food_col_subset.dropna(inplace=True)
df_food_col_subset
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂

df_food[["calories_day","weight","Gender"]]
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.
df_food_col_subset = df_food_col_subset.apply(pd.to_numeric, errors="coerce")
df_food_col_subset.dropna(inplace=True)
df_food_col_subset
# Out:
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %%
# checking dtypes
df_food_col_subset.dtypes
# Out:
# calories_day    float64
# weight          float64
# Gender            int64
# dtype: object

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_col_subset.to_csv("../data/food_coded_cleaned.csv",index=False)

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.

with open("../data/food_coded_cleaned.csv") as f:
    for _ in range(5):
        print(f.readline(), end="")
# Out:
# calories_day,weight,Gender
# 3.0,155.0,1
# 2.0,190.0,1
# 3.0,190.0,1
# 3.0,180.0,2

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.
df_salary = pd.read_csv("../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv", sep="\t")
df_salary
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 28057                              Veterinarian
# 28058                         Systems Architect
# 28059                 Risk Management Associate
# 28060                                        IT
# 28061                    Clinical physiologist
#
#       If your job title needs additional context, please clarify here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                NaN
# 28060                                                NaN
# 28061                                                NaN
#
#       What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                                 55,000
# 1                                                 54,600
# 2                                                 34,000
# 3                                                 62,000
# 4                                                 60,000
# ...                                                  ...
# 28057                                             135000
# 28058                                             109000
# 28059                                               1200
# 28060                                               1700
# 28061                                            1200000
#
#        How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                    0.0
# 1                                                 4000.0
# 2                                                    NaN
# 3                                                 3000.0
# 4                                                 7000.0
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                0.0
# 28060                                               10.0
# 28061                                                NaN
#
#       Please indicate the currency  \
# 0                              USD
# 1                              GBP
# 2                              USD
# 3                              USD
# 4                              USD
# ...                            ...
# 28057                          USD
# 28058                          USD
# 28059                          USD
# 28060                          USD
# 28061                        Other
#
#       If "Other," please indicate the currency here:   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 28057                                             NaN
# 28058                                             NaN
# 28059                                             NaN
# 28060                                             NaN
# 28061                                             NGN
#
#       If your income needs additional context, please provide it here:  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28057                                                NaN
# 28058                                                NaN
# 28059                                                NaN
# 28060                                                NaN
# 28061                                                NaN
#
#       What country do you work in?  \
# 0                    United States
# 1                   United Kingdom
# 2                               US
# 3                              USA
# 4                               US
# ...                            ...
# 28057               United States
# 28058                          USA
# 28059                      Myanmar
# 28060                        Burma
# 28061                     Nigeria
#
#       If you're in the U.S., what state do you work in?  \
# 0                                         Massachusetts
# 1                                                   NaN
# 2                                             Tennessee
# 3                                             Wisconsin
# 4                                        South Carolina
# ...                                                 ...
# 28057                                          Missouri
# 28058                                           Georgia
# 28059                                          Colorado
# 28060                                               NaN
# 28061                                               NaN
#
#       What city do you work in?  \
# 0                        Boston
# 1                     Cambridge
# 2                   Chattanooga
# 3                     Milwaukee
# 4                    Greenville
# ...                         ...
# 28057               Wentzville
# 28058                   Atlanta
# 28059                    Yangon
# 28060                    Yangon
# 28061                     Lagos
#
#       How many years of professional work experience do you have overall?  \
# 0                                              5-7 years
# 1                                           8 - 10 years
# 2                                            2 - 4 years
# 3                                           8 - 10 years
# 4                                           8 - 10 years
# ...                                                  ...
# 28057                                      11 - 20 years
# 28058                                          5-7 years
# 28059                                        2 - 4 years
# 28060                                        2 - 4 years
# 28061                                        2 - 4 years
#
#       How many years of professional work experience do you have in your field?  \
# 0                                              5-7 years
# 1                                              5-7 years
# 2                                            2 - 4 years
# 3                                              5-7 years
# 4                                              5-7 years
# ...                                                  ...
# 28057                                      11 - 20 years
# 28058                                          5-7 years
# 28059                                        2 - 4 years
# 28060                                     1 year or less
# 28061                                        2 - 4 years
#
#       What is your highest level of education completed? What is your gender?  \
# 0                                        Master's degree                Woman
# 1                                         College degree           Non-binary
# 2                                         College degree                Woman
# 3                                         College degree                Woman
# 4                                         College degree                Woman
# ...                                                  ...                  ...
# 28057                 Professional degree (MD, JD, etc.)                Woman
# 28058                                     College degree                  Man
# 28059                                       Some college                  Man
# 28060                                       Some college                  Man
# 28061                                     College degree                Woman
#
#       What is your race? (Choose all that apply.)
# 0                                           White
# 1                                           White
# 2                                           White
# 3                                           White
# 4                                           White
# ...                                           ...
# 28057                                       White
# 28058                                       White
# 28059                     Asian or Asian American
# 28060                     Asian or Asian American
# 28061                   Black or African American
#
# [28062 rows x 18 columns]

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
print(f"Rows: {df_salary.shape[0]}, Columns: {df_salary.shape[1]}")
# Out:
# Rows: 28062, Columns: 18

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.dtypes.to_frame().reset_index().rename(columns={'index':"Column",0:"type"})
# Out:
#                                                Column     type
# 0                                           Timestamp      str
# 1                                    How old are you?      str
# 2                       What industry do you work in?      str
# 3                                           Job title      str
# 4   If your job title needs additional context, pl...      str
# 5   What is your annual salary? (You'll indicate t...      str
# 6   How much additional monetary compensation do y...  float64
# 7                        Please indicate the currency      str
# 8     If "Other," please indicate the currency here:       str
# 9   If your income needs additional context, pleas...      str
# 10                       What country do you work in?      str
# 11  If you're in the U.S., what state do you work in?      str
# 12                          What city do you work in?      str
# 13  How many years of professional work experience...      str
# 14  How many years of professional work experience...      str
# 15  What is your highest level of education comple...      str
# 16                               What is your gender?      str
# 17        What is your race? (Choose all that apply.)      str

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
column_names = ["timestamp", "age", "industry", "title", "title_context", "salary", 
                "additional_compensation", "currency", "other_currency", "salary_context", "country", 
                "state", "city", "total_yoe", "field_yoe", 
                "highest_education_completed", "gender", "race"]

df_salary.columns = column_names
df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# 2                      NaN      USD            NaN            NaN
# 3                   3000.0      USD            NaN            NaN
# 4                   7000.0      USD            NaN            NaN
#
#           country           state         city     total_yoe    field_yoe  \
# 0   United States   Massachusetts       Boston     5-7 years    5-7 years
# 1  United Kingdom             NaN    Cambridge  8 - 10 years    5-7 years
# 2              US       Tennessee  Chattanooga   2 - 4 years  2 - 4 years
# 3             USA       Wisconsin    Milwaukee  8 - 10 years    5-7 years
# 4              US  South Carolina   Greenville  8 - 10 years    5-7 years
#
#   highest_education_completed      gender   race
# 0             Master's degree       Woman  White
# 1              College degree  Non-binary  White
# 2              College degree       Woman  White
# 3              College degree       Woman  White
# 4              College degree       Woman  White

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary["industry"].value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.
df_salary_tech = df_salary[df_salary["industry"] == "Computing or Tech"].reset_index(drop=True).copy()
df_salary_tech.head()
# Out:
#             timestamp    age           industry  \
# 0  4/27/2021 11:02:22  25-34  Computing or Tech
# 1  4/27/2021 11:03:01  45-54  Computing or Tech
# 2  4/27/2021 11:04:04  25-34  Computing or Tech
# 3  4/27/2021 11:04:04  25-34  Computing or Tech
# 4  4/27/2021 11:04:07  35-44  Computing or Tech
#
#                                       title                 title_context  \
# 0  Change & Internal Communications Manager                           NaN
# 1                           Systems Analyst  Data developer/ETL Developer
# 2               Principal Software Engineer                           NaN
# 3                      Intelligence Analyst                           NaN
# 4                          Mobile developer                           NaN
#
#     salary  additional_compensation currency other_currency  \
# 0   54,600                   4000.0      GBP            NaN
# 1  112,000                  10000.0      USD            NaN
# 2  187,500                   5000.0      USD            NaN
# 3  110,000                  20000.0      USD            NaN
# 4  144,600                   2500.0      USD            NaN
#
#                   salary_context         country          state  \
# 0                            NaN  United Kingdom            NaN
# 1                            NaN              US       Missouri
# 2                            NaN   United States   Pennsylvania
# 3  Around 20,000 a year in stock             USA       Virginia
# 4                            NaN             USA  Massachusetts
#
#             city      total_yoe      field_yoe highest_education_completed  \
# 0      Cambridge   8 - 10 years      5-7 years              College degree
# 1      St. Louis  21 - 30 years  21 - 30 years              College degree
# 2     Pittsburgh   8 - 10 years      5-7 years              College degree
# 3  Arlington, VA   8 - 10 years   8 - 10 years             Master's degree
# 4         Boston      5-7 years      5-7 years                         PhD
#
#        gender   race
# 0  Non-binary  White
# 1       Woman  White
# 2       Woman  White
# 3         Man  White
# 4       Woman  White

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.
df_salary_tech.shape
# Out:
# (4699, 18)

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!
df_salary_tech = df_salary_tech[df_salary_tech.currency == "USD"].reset_index(drop = True)
df_salary_tech
# Out:
#                timestamp    age           industry  \
# 0     4/27/2021 11:03:01  45-54  Computing or Tech
# 1     4/27/2021 11:04:04  25-34  Computing or Tech
# 2     4/27/2021 11:04:04  25-34  Computing or Tech
# 3     4/27/2021 11:04:07  35-44  Computing or Tech
# 4     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                  ...    ...                ...
# 3772   6/3/2024 16:15:43  18-24  Computing or Tech
# 3773   7/1/2024 20:05:58  25-34  Computing or Tech
# 3774   7/3/2024 14:02:01  25-34  Computing or Tech
# 3775  7/23/2024 17:51:03  25-34  Computing or Tech
# 3776  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                        title                 title_context  \
# 0                            Systems Analyst  Data developer/ETL Developer
# 1                Principal Software Engineer                           NaN
# 2                       Intelligence Analyst                           NaN
# 3                           Mobile developer                           NaN
# 4                    Product Design Director                           NaN
# ...                                      ...                           ...
# 3772         Research Data Analyst Associate                           NaN
# 3773                    Junior data analyst                            NaN
# 3774  Senior Global Public Relations Manager                           NaN
# 3775                       Systems Architect                           NaN
# 3776                                      IT                           NaN
#
#        salary  additional_compensation currency other_currency  \
# 0     112,000                  10000.0      USD            NaN
# 1     187,500                   5000.0      USD            NaN
# 2     110,000                  20000.0      USD            NaN
# 3     144,600                   2500.0      USD            NaN
# 4     200,850                  40000.0      USD            NaN
# ...       ...                      ...      ...            ...
# 3772    60000                      0.0      USD            NaN
# 3773    35000                  15000.0      USD            NaN
# 3774   144000                  15000.0      USD            NaN
# 3775   109000                      NaN      USD            NaN
# 3776     1700                     10.0      USD            NaN
#
#                      salary_context        country           state  \
# 0                               NaN             US        Missouri
# 1                               NaN  United States    Pennsylvania
# 2     Around 20,000 a year in stock            USA        Virginia
# 3                               NaN            USA   Massachusetts
# 4                               NaN            USA  North Carolina
# ...                             ...            ...             ...
# 3772                            NaN  United States        Illinois
# 3773                            NaN            Usa         Alabama
# 3774                            NaN            Usa   Massachusetts
# 3775                            NaN            USA         Georgia
# 3776                            NaN          Burma             NaN
#
#                                               city      total_yoe  \
# 0                                        St. Louis  21 - 30 years
# 1                                       Pittsburgh   8 - 10 years
# 2                                    Arlington, VA   8 - 10 years
# 3                                           Boston      5-7 years
# 4                                      Chapel Hill  11 - 20 years
# ...                                            ...            ...
# 3772                                      Evanston    2 - 4 years
# 3773                                      Alabama     2 - 4 years
# 3774  Boise-but remote. Company located in Boston    8 - 10 years
# 3775                                       Atlanta      5-7 years
# 3776                                        Yangon    2 - 4 years
#
#            field_yoe highest_education_completed gender  \
# 0      21 - 30 years              College degree  Woman
# 1          5-7 years              College degree  Woman
# 2       8 - 10 years             Master's degree    Man
# 3          5-7 years                         PhD  Woman
# 4      11 - 20 years              College degree  Woman
# ...              ...                         ...    ...
# 3772  1 year or less              College degree  Woman
# 3773     2 - 4 years              College degree  Woman
# 3774    8 - 10 years             Master's degree  Woman
# 3775       5-7 years              College degree    Man
# 3776  1 year or less                Some college    Man
#
#                            race
# 0                         White
# 1                         White
# 2                         White
# 3                         White
# 4                         White
# ...                         ...
# 3772                      White
# 3773  Black or African American
# 3774                      White
# 3775                      White
# 3776    Asian or Asian American
#
# [3777 rows x 18 columns]

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech.country.value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.
df_salary_tech.loc[df_salary_tech.country
                   .isin(df_salary_tech.country.value_counts().head(5).index.to_list()), 
                   "country"] = "US"

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech.country.value_counts()
# Out:
# country
# US                           3408
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# Poland                          2
# France                          2
# U.S.A                           2
# United States of america        2
# US                              1
# Uniyed states                   1
# America                         1
# Puerto Rico                     1
# U.s.                            1
#  US                             1
# United State                    1
# Cuba                            1
# Danmark                         1
# Italy                           1
# International                   1
# United Stated                   1
# Remote (philippines)            1
# Singapore                       1
# Uruguay                         1
# Mexico                          1
# Canada                          1
# United Stateds                  1
# ISA                             1
# singapore                       1
# Pakistan                        1
# Netherlands                     1
# China                           1
# San Francisco                   1
# Romania                         1
# United STates                   1
# Japan                           1
# United Stares                   1
# Australian                      1
# Denmark                         1
# Jamaica                         1
# Unites States                   1
# Thailand                        1
# U.S.A                           1
# Colombia                        1
# denmark                         1
# Ghana                           1
# Nigeria                         1
# ss                              1
# Nigeria                         1
# Burma                           1
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_tech.loc[df_salary_tech.country.isin(df_salary_tech.country.value_counts().head(11).index), "country"] = "US"
df_salary_tech["country"].value_counts()
# Out:
# country
# US                          3691
# Israel                         5
# Canada                         4
# U.S.                           2
# United State of America        2
# Unite States                   2
# Australia                      2
# UnitedStates                   2
# India                          2
# U.S                            2
# Usa                            2
# United States Of America       2
# Spain                          2
# Brazil                         2
# United Kingdom                 2
# united States                  2
# New Zealand                    2
# Poland                         2
# France                         2
# U.S.A                          2
# United States of america       2
# US                             1
# Uniyed states                  1
# America                        1
# Puerto Rico                    1
# U.s.                           1
#  US                            1
# United State                   1
# Cuba                           1
# Danmark                        1
# Italy                          1
# International                  1
# United Stated                  1
# Remote (philippines)           1
# Singapore                      1
# Uruguay                        1
# Mexico                         1
# Canada                         1
# United Stateds                 1
# ISA                            1
# singapore                      1
# Pakistan                       1
# Netherlands                    1
# China                          1
# San Francisco                  1
# Romania                        1
# United STates                  1
# Japan                          1
# United Stares                  1
# Australian                     1
# Denmark                        1
# Jamaica                        1
# Unites States                  1
# Thailand                       1
# U.S.A                          1
# Colombia                       1
# denmark                        1
# Ghana                          1
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Burma                          1
# Name: count, dtype: int64

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_salary_tech[df_salary_tech['country'] == "US"].groupby('state')['salary']\
    .agg(["min", "mean", "max"]).sort_values(by = "mean", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Find the minimum, mean, and maximum salary in USD by U.S. state.
#       2 df_salary_tech[df_salary_tech['country'] == "US"].groupby('state')['salary']\
# ----> 3     .agg(["min", "mean", "max"]).sort_values(by = "mean", ascending = False)
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     520     for idx, (name, func) in enumerate(arg):
#     521         key = base.OutputKey(label=name, position=idx)
# --> 522         results[key] = self.aggregate(func, *args, **kwargs)
#     524 if any(isinstance(x, DataFrame) for x in results.values()):
#     525     from pandas import concat
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:2295, in SingleBlockManager.grouped_reduce(self, func)
#    2293 def grouped_reduce(self, func):
#    2294     arr = self.array
# -> 2295     res = func(arr)
#    2296     index = default_index(len(res))
#    2298     mgr = type(self).from_array(res, index)
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/Downloads/CTP-2026/.venv/lib/python3.13/site-packages/pandas/core/arrays/base.py:2808, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2794 if isinstance(self.dtype, StringDtype):
#    2795     # StringArray
#    2796     if op.how in [
#    2797         "prod",
#    2798         "mean",
#    (...)   2806         "kurt",
#    2807     ]:
# -> 2808         raise TypeError(
#    2809             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2810         )
#    2811     if op.how not in ["any", "all"]:
#    2812         # Fail early to avoid conversion to object
#    2813         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.
df_salary_tech.salary = pd.to_numeric(
    df_salary_tech.salary.astype(str).str.replace('$','',regex=False)
    .str.replace(',','').str.strip()
    , errors="coerce")

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_tech[df_salary_tech['country'] == "US"].groupby('state')['salary']\
    .agg(["min", "mean", "max"]).sort_values(by = "mean", ascending = False)
# Out:
#                                    min           mean      max
# state
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Florida                          28800  158501.909091  2600000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155224.893130   875000
# Washington                          72  151525.934328   950000
# New York                         14000  148224.909884   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  134969.109635  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# New Jersey                       40000  128802.475000   603000
# Connecticut                      62400  128375.000000   270000
# Virginia                         43642  127370.512821   450000
# Colorado                         45000  127293.993007   630000
# Massachusetts, Rhode Island     125000  125000.000000   125000
# Oregon                           16200  123790.238994   320000
# Georgia, Washington             123000  123000.000000   123000
# West Virginia                   116500  120500.000000   125000
# Illinois                         13500  119268.242604   315000
# Maryland                         51260  118916.377358   205000
# Georgia                          29120  117893.098765   250000
# Louisiana, Washington           117000  117000.000000   117000
# Delaware                         63000  116600.000000   169000
# South Dakota                     86000  115333.333333   150000
# Texas                            10700  113451.882353   280000
# Tennessee                        36550  112847.058824   240000
# Wisconsin                            1  112717.192771   920000
# Alaska                           67000  112500.000000   158000
# Pennsylvania                     32000  111851.901786   237000
# Vermont                          65000  111781.250000   200000
# Idaho                            50000  111527.692308   312000
# Rhode Island                     76000  111491.666667   180000
# District of Columbia, Virginia  109200  109200.000000   109200
# Ohio                             32240  106868.212121   954000
# Minnesota                        34000  106752.793103   230000
# Utah                             33280  105836.479167   245000
# New York, Texas                 105000  105000.000000   105000
# Massachusetts, New Hampshire    105000  105000.000000   105000
# North Carolina                   29000  104972.127273   260000
# Arizona                          35000  104491.891892   210000
# Maine                            50000  103571.428571   173000
# South Carolina                   40000  102111.111111   205000
# Iowa                             47840   99729.736842   160000
# Kansas                           41500   99565.052632   167000
# North Dakota                     45760   97880.000000   150000
# Michigan                         36800   97723.055556   235000
# Montana                          65000   95500.000000   145000
# Missouri                            80   95317.652174   200000
# Arizona, Utah                    95000   95000.000000    95000
# Mississippi                      94000   94000.000000    94000
# New Hampshire                       55   93003.437500   193000
# Alabama                          29120   92510.000000   350000
# Kentucky                         39000   92375.000000   170000
# Nebraska                         43000   90975.294118   166400
# Indiana                          15000   88566.647059   200000
# Oklahoma                         28536   87929.500000   180000
# Massachusetts, Pennsylvania      83000   83000.000000    83000
# Arkansas                         55000   81682.300000   144000
# California, Maryland             81500   81500.000000    81500
# Louisiana                        35360   79884.444444   110000
# Alabama, Montana                 72000   72000.000000    72000

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_tech.timestamp = pd.to_datetime(df_salary_tech.timestamp)

df_salary_tech_select = df_salary_tech[df_salary_tech.timestamp.dt.year.isin([2021,2022,2023])].copy()

df_salary_tech_select[df_salary_tech_select.country == "US"].groupby("state")["salary"]\
    .agg(["min","mean","max"]).sort_values(by="mean", ascending=False)
# Out:
#                                    min           mean      max
# state
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155355.206422   875000
# Washington                          72  151676.760479   950000
# New York                         14000  148224.909884   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  134939.006667  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# New Jersey                       40000  128802.475000   603000
# Connecticut                      62400  128375.000000   270000
# Virginia                         43642  127370.512821   450000
# Colorado                         45000  127293.993007   630000
# Massachusetts, Rhode Island     125000  125000.000000   125000
# Oregon                           16200  123790.238994   320000
# Georgia, Washington             123000  123000.000000   123000
# West Virginia                   116500  120500.000000   125000
# Illinois                         13500  119621.029762   315000
# Maryland                         51260  118916.377358   205000
# Georgia                          29120  118004.262500   250000
# Louisiana, Washington           117000  117000.000000   117000
# Delaware                         63000  116600.000000   169000
# South Dakota                     86000  115333.333333   150000
# Texas                            10700  113451.882353   280000
# Florida                          28800  113288.981481   400000
# Tennessee                        36550  112847.058824   240000
# Wisconsin                            1  112717.192771   920000
# Alaska                           67000  112500.000000   158000
# Pennsylvania                     32000  111851.901786   237000
# Vermont                          65000  111781.250000   200000
# Idaho                            50000  111527.692308   312000
# Rhode Island                     76000  111491.666667   180000
# South Carolina                   40000  109875.000000   205000
# District of Columbia, Virginia  109200  109200.000000   109200
# Minnesota                        34000  107063.872093   230000
# Ohio                             32240  106868.212121   954000
# Utah                             33280  105836.479167   245000
# New York, Texas                 105000  105000.000000   105000
# Massachusetts, New Hampshire    105000  105000.000000   105000
# North Carolina                   29000  104880.128440   260000
# Arizona                          35000  104491.891892   210000
# Maine                            50000  103571.428571   173000
# Iowa                             47840   99729.736842   160000
# Kansas                           41500   99565.052632   167000
# North Dakota                     45760   97880.000000   150000
# Alabama                          29120   97738.181818   350000
# Michigan                         36800   97723.055556   235000
# Montana                          65000   95500.000000   145000
# Missouri                            80   95317.652174   200000
# Arizona, Utah                    95000   95000.000000    95000
# Mississippi                      94000   94000.000000    94000
# New Hampshire                       55   93003.437500   193000
# Kentucky                         39000   92375.000000   170000
# Nebraska                         43000   90975.294118   166400
# Indiana                          15000   88566.647059   200000
# Oklahoma                         28536   87929.500000   180000
# Massachusetts, Pennsylvania      83000   83000.000000    83000
# Arkansas                         55000   81682.300000   144000
# California, Maryland             81500   81500.000000    81500
# Louisiana                        35360   79884.444444   110000
# Alabama, Montana                 72000   72000.000000    72000

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
