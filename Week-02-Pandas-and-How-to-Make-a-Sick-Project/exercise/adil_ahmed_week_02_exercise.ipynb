# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Install pandas and numpy if the active Python environment does not have them. Using Python venv is recommended when you are doing so.
# %pip install pandas numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: /Users/adil/Desktop/ds-fall-2026/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Food choices data set into a new variable, `df_food`.

# %%
# Load the Food choices data set.

food_data_set_path = '../data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)

df_food.shape
# Out:
# (125, 61)

# %%
# Try to print or display it nicely.

print('Rows:', df_food.shape[0])
print('Columns:', df_food.shape[1])
# Out:
# Rows: 125
# Columns: 61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

df_food.dtypes
# Out:
# GPA                     str
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports             str
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight                  str
# Length: 61, dtype: object

# %%
pd.set_option("display.max_rows", 100) # Set pandas to render up to 100 rows first. Default caps to 10 and takes the middle chunk out to make the DataFrame fit.

# Try to display the column information as a nice pandas DataFrame.

df_food_types = pd.DataFrame(df_food.dtypes, columns=['type'])
df_food_types
# Out:
#                                  type
# GPA                               str
# Gender                          int64
# breakfast                       int64
# calories_chicken                int64
# calories_day                  float64
# calories_scone                float64
# coffee                          int64
# comfort_food                      str
# comfort_food_reasons              str
# comfort_food_reasons_coded    float64
# cook                          float64
# comfort_food_reasons_coded.1    int64
# cuisine                       float64
# diet_current                      str
# diet_current_coded              int64
# drink                         float64
# eating_changes                    str
# eating_changes_coded            int64
# eating_changes_coded1           int64
# eating_out                      int64
# employment                    float64
# ethnic_food                     int64
# exercise                      float64
# father_education              float64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns? (Assign the result to a new variable, `df_food_col_subset`.)

# %%
# Remove ‘em.

df_food_col_subset = df_food[['calories_day', 'weight', 'Gender']].copy()
df_food_col_subset.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %%
# Is there a second way to remove columns?

cols_to_drop = []
for col in df_food.columns:
    if col not in ['calories_day', 'weight', 'Gender']:
        cols_to_drop.append(col)

df_food_col_subset_2 = df_food.drop(columns=cols_to_drop)
df_food_col_subset_2.head()
# Out:
#    Gender  calories_day                    weight
# 0       2           NaN                       187
# 1       1           3.0                       155
# 2       1           4.0  I'm not answering this.
# 3       1           3.0             Not sure, 240
# 4       1           2.0                       190

# %%
# 🚀 Extra credit: What about a third way to remove columns?

df_food_col_subset_3 = df_food.loc[:, ['calories_day', 'weight', 'Gender']]
df_food_col_subset_3.head()
# Out:
#    calories_day                    weight  Gender
# 0           NaN                       187       2
# 1           3.0                       155       1
# 2           4.0  I'm not answering this.        1
# 3           3.0             Not sure, 240       1
# 4           2.0                       190       1

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

df_food_col_subset.isnull().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %%
# 🚀 Extra credit: Try to display the NaN sums as a nice pandas DataFrame.

pd.DataFrame(df_food_col_subset.isnull().sum(), columns=['nan_count'])
# Out:
#               nan_count
# calories_day         19
# weight                2
# Gender                0

# %%
# 🚀 Extra credit: You can turn one line of code into multiple lines of code using a backslash as a continuation character to break up what would otherwise be a long line.

df_food_nans = df_food_col_subset.isnull() \
    .sum()

pd.DataFrame(df_food_nans, columns=['nan_count'])
# Out:
#               nan_count
# calories_day         19
# weight                2
# Gender                0

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em in-place.

df_food_col_subset.dropna(inplace=True)
df_food_col_subset.shape
# Out:
# (104, 3)

# %%
# 🚀 Extra credit: Check if the in-place modifications also affected the original DataFrame, df_food. 🙂

df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that in-place.

df_food_col_subset['weight'] = pd.to_numeric(df_food_col_subset['weight'], errors='coerce')
df_food_col_subset.dropna(subset=['weight'], inplace=True)
df_food_col_subset.dtypes
# Out:
# calories_day    float64
# weight          float64
# Gender            int64
# dtype: object

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food_col_subset.to_csv('../data/food_coded_cleaned.csv', index=False)

# %%
# 🚀 Extra credit: Load and print a few lines of the saved file as plain text.

with open('../data/food_coded_cleaned.csv', 'rt') as text_file:
    for line in text_file.readlines()[:5]:
        print(line)
# Out:
# calories_day,weight,Gender
#
# 3.0,155.0,1
#
# 2.0,190.0,1
#
# 3.0,190.0,1
#
# 3.0,180.0,2

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %% [markdown]
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a new variable, `df_salary`.

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set.

salary_data_set_path = '../data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv'

df_salary = pd.read_csv(salary_data_set_path, sep='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

df_salary.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                   str
# How old are you?                                                                                                                                                                                                                            str
# What industry do you work in?                                                                                                                                                                                                               str
# Job title                                                                                                                                                                                                                                   str
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em in-place.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.columns = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
                     'additional_compensation', 'currency', 'other_currency', 'salary_context',
                     'country', 'state', 'city', 'total_yoe', 'field_yoe',
                     'highest_education_completed', 'gender', 'race']
df_salary.head()
# Out:
#             timestamp    age                       industry  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                       title title_context  salary  \
# 0        Research and Instruction Librarian           NaN  55,000
# 1  Change & Internal Communications Manager           NaN  54,600
# 2                      Marketing Specialist           NaN  34,000
# 3                           Program Manager           NaN  62,000
# 4                        Accounting Manager           NaN  60,000
#
#    additional_compensation currency other_currency salary_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                               4699
# Education (Higher Education)                    2464
# Nonprofits                                      2419
# Health care                                     1896
# Government and Public Administration            1889
#                                                 ...
# Undergrad student                                  1
# Concrete Construction                              1
# I'm currently a student and don't have a job       1
# Student                                            1
# Wine & Spirits                                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new variable, `df_salary_tech`.

# %%
# Filtery filter.

select_condition = df_salary['industry'] == 'Computing or Tech'

df_salary_tech = df_salary[select_condition].copy()

# %% [markdown]
# Do a sanity check by counting.

# %%
# Sanity check count.

df_salary_tech['industry'].value_counts()
# Out:
# industry
# Computing or Tech    4699
# Name: count, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter (in place) for just the jobs that pay in USD!

select_condition = df_salary_tech['currency'] == 'USD'

df_salary_tech = df_salary_tech[select_condition].copy()
df_salary_tech['currency'].value_counts()
# Out:
# currency
# USD    3777
# Name: count, dtype: int64

# %% [markdown]
# What we really want know is how each U.S. state pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_tech['country'].value_counts()
# Out:
# country
# United States                1576
# USA                          1222
# US                            412
# U.S.                          108
# United States of America       90
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# ...

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all in-place with 'US'.

mapping_dict = {
    'United States': 'US',
    'USA': 'US',
    'U.S.': 'US',
    'United States of America': 'US'
}

df_salary_tech['country'] = df_salary_tech['country'].replace(mapping_dict)

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary_tech['country'].value_counts()
# Out:
# country
# US                           3408
# United States                  68
# Usa                            59
# USA                            56
# usa                            28
# United states                  23
# united states                  14
# Us                             12
# us                              9
# U.S.A.                          7
# United States of America        7
# Israel                          5
# Canada                          4
# U.S.                            2
# United State of America         2
# Unite States                    2
# Australia                       2
# UnitedStates                    2
# India                           2
# U.S                             2
# Usa                             2
# United States Of America        2
# Spain                           2
# Brazil                          2
# United Kingdom                  2
# united States                   2
# New Zealand                     2
# ...

# %% [markdown]
# Did you notice anything interesting?

# %%
# 🚀 Extra credit: Resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

country_lower = df_salary_tech['country'].str.strip().str.lower().str.replace('.', '')

condition_1 = country_lower.isin(['us', 'usa', 'america'])
condition_2 = country_lower.str.contains('state')

df_salary_tech['country'] = np.where(condition_1 | condition_2, 'US', df_salary_tech['country'])

# %%
# 🚀 Extra credit: If you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_salary_tech['country'].value_counts()
# Out:
# country
# US                      3722
# Israel                     5
# Canada                     4
# Australia                  2
# India                      2
# Spain                      2
# Brazil                     2
# United Kingdom             2
# New Zealand                2
# Poland                     2
# France                     2
# Puerto Rico                1
# Cuba                       1
# Danmark                    1
# Italy                      1
# International              1
# Remote (philippines)       1
# Singapore                  1
# Uruguay                    1
# Mexico                     1
# Canada                     1
# ISA                        1
# singapore                  1
# Pakistan                   1
# Netherlands                1
# China                      1
# San Francisco              1
# Romania                    1
# Japan                      1
# United Stares              1
# Australian                 1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary_tech = df_salary_tech[df_salary_tech['country'] == 'US'].copy()

gb = df_salary_tech.groupby('state')
gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 6
#       2
#       3 df_salary_tech = df_salary_tech[df_salary_tech['country'] == 'US'].copy()
#       4
#       5 gb = df_salary_tech.groupby('state')
# ----> 6 gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
#
# File ~/Desktop/ds-fall-2026/.venv/lib/python3.14/site-packages/pandas/core/groupby/generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# ...

# %% [markdown]
#  Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed. 🤔

# %%
# Fix it in-place.

df_salary_tech['salary'] = df_salary_tech['salary'].str.replace(',', '')
df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

gb = df_salary_tech.groupby('state')
gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Florida                          28800  157457.232143  2600000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155019.612462   875000
# Washington                          72  151423.670588   950000
# New York                         14000  148054.638968   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  135213.537954  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# ...

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech['timestamp'] = pd.to_datetime(df_salary_tech['timestamp'])

select_condition = df_salary_tech['timestamp'].dt.year.isin([2021, 2022, 2023])
df_salary_tech_years = df_salary_tech[select_condition].copy()

gb = df_salary_tech_years.groupby('state')
gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                    min           mean      max
# state
# Michigan, Texas, Washington     340000  340000.000000   340000
# California, Oregon              200000  200000.000000   200000
# California, Colorado            176000  176000.000000   176000
# Georgia, Massachusetts          175000  175000.000000   175000
# Alabama, District of Columbia   156000  156000.000000   156000
# California                           0  155149.018265   875000
# Washington                          72  151571.970501   950000
# New York                         14000  148054.638968   590000
# Nevada                           38000  141310.000000   425000
# New Jersey, New York            135000  137500.000000   140000
# Massachusetts                    37000  135184.443709  1650000
# District of Columbia             10000  132318.036364   267500
# New Mexico                       70000  132200.000000   300000
# Utah, Vermont                   130000  130000.000000   130000
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
select_condition = df_salary['currency'] == 'USD'
df_salary = df_salary[select_condition].copy()

df_salary['country'] = df_salary['country'].replace(mapping_dict)

country_lower = df_salary['country'].str.strip().str.lower().str.replace('.', '')
condition_1 = country_lower.isin(['us', 'usa', 'america'])
condition_2 = country_lower.str.contains('state')
df_salary['country'] = np.where(condition_1 | condition_2, 'US', df_salary['country'])

df_salary = df_salary[df_salary['country'] == 'US'].copy()

df_salary['salary'] = df_salary['salary'].str.replace(',', '')
df_salary['salary'] = pd.to_numeric(df_salary['salary'], errors='coerce')

gb = df_salary.groupby('state')
gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
#                                                        min           mean  \
# state
# Michigan, Texas, Washington                         340000  340000.000000
# Indiana, Ohio                                       245000  245000.000000
# Alaska                                               27040  232275.078125
# Colorado, Nevada                                    190000  190000.000000
# California, Texas                                   185000  185000.000000
# ...                                                    ...            ...
# District of Columbia, Washington                     35000   35000.000000
# Delaware, Pennsylvania                               35000   35000.000000
# Alabama, California                                  29120   29120.000000
# District of Columbia, Maryland, Pennsylvania, V...   27040   27040.000000
# Maryland, New York                                   14000   14000.000000
#
#                                                          max
# state
# ...

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
gb = df_salary.groupby('state')
df_salary_summary = gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)

df_salary_summary.style.format('${:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_571b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_571b3_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_571b3_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_571b3_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_571b3_level0_row0" class="row_heading level0 row0" >Michigan, Texas, Washington</th>
#       <td id="T_571b3_row0_col0" class="data row0 col0" >$340,000.00</td>
#       <td id="T_571b3_row0_col1" class="data row0 col1" >$340,000.00</td>
#       <td id="T_571b3_row0_col2" class="data row0 col2" >$340,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
df_salary_single_state = df_salary.dropna(subset=['state'])

select_condition = df_salary_single_state['state'].str.contains(',')
df_salary_single_state = df_salary_single_state[~select_condition]

gb = df_salary_single_state.groupby('state')
gb['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False).style.format('${:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa9cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa9cc_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_aa9cc_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_aa9cc_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa9cc_level0_row0" class="row_heading level0 row0" >Alaska</th>
#       <td id="T_aa9cc_row0_col0" class="data row0 col0" >$27,040.00</td>
#       <td id="T_aa9cc_row0_col1" class="data row0 col1" >$232,275.08</td>
#       <td id="T_aa9cc_row0_col2" class="data row0 col2" >$10,000,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
gb = df_salary_single_state.groupby('state')
df_salary_quantiles = gb['salary'].describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95])

df_salary_quantiles[['count', 'min', '5%', '25%', '50%', '75%', '95%', 'max']].sort_values('50%', ascending=False)
# Out:
#                        count      min        5%       25%       50%  \
# state
# California            2593.0      0.0  42000.00  72000.00  100440.0
# Washington            1182.0     72.0  40000.00  65000.00   91000.0
# New York              2169.0     80.0  40928.00  64575.00   90000.0
# District of Columbia   976.0     40.0  48000.00  66450.00   90000.0
# Massachusetts         1518.0    155.0  42000.00  64000.00   86000.0
# Connecticut            237.0      0.0  33830.00  62000.00   82000.0
# Maryland               563.0      0.0  40100.00  60000.00   82000.0
# Virginia               782.0     57.0  37402.00  58812.50   80616.5
# Delaware                47.0  35000.0  40480.00  57546.50   80145.0
# Oregon                 623.0      0.0  36460.00  58100.00   78000.0
# Colorado               630.0     65.0  38939.00  58029.00   76000.0
# Illinois              1206.0      0.0  37440.00  56000.00   76000.0
# Texas                 1262.0      0.0  35069.40  55000.00   75325.0
# ...
